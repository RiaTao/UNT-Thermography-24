# %%
import scipy,io
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization, SimpleRNN, Input, TimeDistributed, GRU, LSTM, Bidirectional
from tensorflow.keras.activations import tanh, softmax, softplus, mish, relu, leaky_relu
from tensorflow.keras.optimizers import AdamW, RMSprop, Nadam, Adam, Lion, LossScaleOptimizer
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.initializers import he_normal
from tensorflow.keras.regularizers import L1, L2
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import RobustScaler, PolynomialFeatures, StandardScaler, normalize, MinMaxScaler
from sklearn.decomposition import PCA
import math
import matplotlib.pyplot as plt
from scikeras.wrappers import KerasClassifier, KerasRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.datasets import make_classification


X_scaler, y_scaler = MinMaxScaler(), MinMaxScaler()

# 10000 Samples
mat = scipy.io.loadmat('../UNT-Thermography-24/GaN_data/data_GaN_8_15micron_1.mat')
mat2 = scipy.io.loadmat('../UNT-Thermography-24/GaN_data/data_GaN_8_15micron_2.mat')
mat3 = scipy.io.loadmat('../UNT-Thermography-24/GaN_data/data_GaN_8_15micron_3.mat')

temp_comb = np.concatenate((mat.get('T_GaN_random'), mat2.get('T_GaN_random'), mat3.get('T_GaN_random')), axis=2)
spectra_comb = np.concatenate((mat.get('Spectrum'), mat2.get('Spectrum'), mat3.get('Spectrum')), axis=2)

samples = spectra_comb.shape[2]

reshaped_spectra = spectra_comb.reshape(-1, samples).T
reshaped_temp = temp_comb.reshape(-1, samples).T

temp_shape = temp_comb.shape
spectra_shape = spectra_comb.shape

# 50000 samples
mat4 = scipy.io.loadmat('../UNT-Thermography-24/GaN_data/data_GaN_8_15micron_4_10000.mat')
mat5 = scipy.io.loadmat('../UNT-Thermography-24/GaN_data/data_GaN_8_15micron_5_10000.mat')
mat6 = scipy.io.loadmat('../UNT-Thermography-24/GaN_data/data_GaN_8_15micron_6_10000.mat')
mat7 = scipy.io.loadmat('../UNT-Thermography-24/GaN_data/data_GaN_8_15micron_7_10000.mat')

temp_comb_all = np.concatenate((temp_comb, mat4.get('T_GaN_random'), mat5.get('T_GaN_random'), mat6.get('T_GaN_random'), mat7.get('T_GaN_random')), axis=2)
spectra_comb_all = np.concatenate((spectra_comb, mat4.get('Spectrum'), mat5.get('Spectrum'), mat6.get('Spectrum'), mat7.get('Spectrum')), axis=2)

samples_all = spectra_comb_all.shape[2]

spectra_all = spectra_comb_all.reshape(-1, samples).T
temp_all = temp_comb_all.reshape(-1, samples).T

spectra_shape = spectra_comb_all.shape
temp_shape = temp_comb_all.shape

spectra_row = spectra_comb_all[0, :, :]
temp_row = temp_comb_all[0, :, :]


# Train, test, validation split
X_train, X_test, y_train, y_test = train_test_split(spectra_all, temp_all, train_size=0.8, random_state=42)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, train_size=0.75, random_state=42)

X_train = X_train.T.reshape(spectra_shape[0], spectra_shape[1], -1)
X_val = X_val.T.reshape(spectra_shape[0], spectra_shape[1], -1)
X_test = X_test.T.reshape(spectra_shape[0], spectra_shape[1], -1)

y_train = y_train.T.reshape(temp_shape[0], temp_shape[1], -1)
y_val = y_val.T.reshape(temp_shape[0], temp_shape[1], -1)
y_test = y_test.T.reshape(temp_shape[0], temp_shape[1], -1)

X_train = X_train.transpose(2, 0, 1)
X_val = X_val.transpose(2, 0, 1)
X_test = X_test.transpose(2, 0, 1)

y_train = y_train.transpose(2, 0, 1)
y_val = y_val.transpose(2, 0, 1)
y_test = y_test.transpose(2, 0, 1)

# Fit and transform the input data (X_train)
X_train_scaled = X_scaler.fit_transform(X_train.reshape(-1, X_train.shape[-1])).reshape(X_train.shape)

# Transform the validation and test data using the same scaler
X_val_scaled = X_scaler.transform(X_val.reshape(-1, X_val.shape[-1])).reshape(X_val.shape)
X_test_scaled = X_scaler.transform(X_test.reshape(-1, X_test.shape[-1])).reshape(X_test.shape)

# Fit and transform the output data (y_train)
y_train_scaled = y_scaler.fit_transform(y_train.reshape(-1, y_train.shape[-1])).reshape(y_train.shape)

# Transform the validation and test data using the same scaler
y_val_scaled = y_scaler.transform(y_val.reshape(-1, y_val.shape[-1])).reshape(y_val.shape)
y_test_scaled = y_scaler.transform(y_test.reshape(-1, y_test.shape[-1])).reshape(y_test.shape)

# %%
spectra_row_reshape = spectra_row.transpose(1, 0)
temp_row_reshape = temp_row.transpose(1, 0)

X_train, X_test, y_train, y_test = train_test_split(spectra_row_reshape, temp_row_reshape, train_size=0.8, random_state=42)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, train_size=.75, random_state=42)

# Fit and transform the input data (X_train)
X_train_scaled = X_scaler.fit_transform(X_train).reshape(X_train.shape)

# Transform the validation and test data using the same scaler
X_val_scaled = X_scaler.transform(X_val).reshape(X_val.shape)
X_test_scaled = X_scaler.transform(X_test).reshape(X_test.shape)

# Fit and transform the output data (y_train)
y_train_scaled = y_scaler.fit_transform(y_train).reshape(y_train.shape)

# Transform the validation and test data using the same scaler
y_val_scaled = y_scaler.transform(y_val).reshape(y_val.shape)
y_test_scaled = y_scaler.transform(y_test).reshape(y_test.shape)

# %%
model = Sequential()
model.add(Input(shape=spectra_row_reshape[1].shape, ))
model.add(Dense(2048, activation='tanh'))
model.add(Dense(1024, activation='tanh'))
model.add(Dense(512, activation='tanh'))
model.add(Dense(256, activation='tanh'))
model.add(Dense(128, activation='tanh'))
model.add(Dense(64, activation='tanh'))
model.add(Dense(32, activation='tanh'))
model.add(Dense(16, activation='tanh'))

# model.add(Dense(1344, activation='tanh'))
# model.add(Dense(1920, activation='tanh'))
# model.add(Dense(1888, activation='tanh'))
# model.add(Dense(192, activation='tanh'))
model.add(Dense(10, activation='linear'))

model.summary()

nadam = Nadam(learning_rate=0.001)
adam = Adam(learning_rate=.001)

early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-6)

model.compile(optimizer=nadam, loss='mae', metrics=['accuracy'])

history = model.fit(X_train_scaled, y_train_scaled, epochs=300, batch_size=256, validation_data=(X_val_scaled, y_val_scaled),
          callbacks=[early_stopping, reduce_lr])


test_loss, test_accuracy = model.evaluate(X_test_scaled, y_test_scaled)
print(f'Test loss: {test_loss}')
print(f'Test accuracy: {test_accuracy}')
# Out:
# Model: "sequential_11"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_94 (Dense)                │ (None, 2048)           │       147,456 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_95 (Dense)                │ (None, 1024)           │     2,098,176 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_96 (Dense)                │ (None, 512)            │       524,800 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_97 (Dense)                │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_98 (Dense)                │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_99 (Dense)                │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_100 (Dense)               │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_101 (Dense)               │ (None, 16)             │           528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_102 (Dense)               │ (None, 10)             │           170 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,945,690 (11.24 MB)
#  Trainable params: 2,945,690 (11.24 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 27ms/step - accuracy: 0.1725 - loss: 0.2267 - val_accuracy: 0.3490 - val_loss: 0.1311 - learning_rate: 0.0010
# Epoch 2/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - accuracy: 0.3533 - loss: 0.1156 - val_accuracy: 0.3930 - val_loss: 0.1177 - learning_rate: 0.0010
# Epoch 3/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 0.4125 - loss: 0.1068 - val_accuracy: 0.4490 - val_loss: 0.1023 - learning_rate: 0.0010
# Epoch 4/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - accuracy: 0.4712 - loss: 0.0969 - val_accuracy: 0.5175 - val_loss: 0.0878 - learning_rate: 0.0010
# Epoch 5/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.5027 - loss: 0.0907 - val_accuracy: 0.5569 - val_loss: 0.0864 - learning_rate: 0.0010
# Epoch 6/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 0.5248 - loss: 0.0855 - val_accuracy: 0.5541 - val_loss: 0.0813 - learning_rate: 0.0010
# Epoch 7/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 41ms/step - accuracy: 0.5314 - loss: 0.0840 - val_accuracy: 0.5513 - val_loss: 0.0753 - learning_rate: 0.0010
# Epoch 8/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 33ms/step - accuracy: 0.5566 - loss: 0.0811 - val_accuracy: 0.5590 - val_loss: 0.0798 - learning_rate: 0.0010
# Epoch 9/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.5606 - loss: 0.0794 - val_accuracy: 0.6033 - val_loss: 0.0723 - learning_rate: 0.0010
# Epoch 10/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - accuracy: 0.5787 - loss: 0.0758 - val_accuracy: 0.5728 - val_loss: 0.0762 - learning_rate: 0.0010
# Epoch 11/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.5819 - loss: 0.0754 - val_accuracy: 0.5636 - val_loss: 0.0791 - learning_rate: 0.0010
# Epoch 12/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 30ms/step - accuracy: 0.5868 - loss: 0.0750 - val_accuracy: 0.5758 - val_loss: 0.0755 - learning_rate: 0.0010
# Epoch 13/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 37ms/step - accuracy: 0.6013 - loss: 0.0726 - val_accuracy: 0.5720 - val_loss: 0.0774 - learning_rate: 0.0010
# Epoch 14/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.6020 - loss: 0.0715 - val_accuracy: 0.6038 - val_loss: 0.0706 - learning_rate: 0.0010
# Epoch 15/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.6089 - loss: 0.0714 - val_accuracy: 0.6318 - val_loss: 0.0691 - learning_rate: 0.0010
# Epoch 16/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 0.6141 - loss: 0.0695 - val_accuracy: 0.6096 - val_loss: 0.0700 - learning_rate: 0.0010
# Epoch 17/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.6102 - loss: 0.0699 - val_accuracy: 0.5980 - val_loss: 0.0735 - learning_rate: 0.0010
# Epoch 18/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - accuracy: 0.6132 - loss: 0.0691 - val_accuracy: 0.6251 - val_loss: 0.0682 - learning_rate: 0.0010
# Epoch 19/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.6219 - loss: 0.0684 - val_accuracy: 0.6051 - val_loss: 0.0691 - learning_rate: 0.0010
# Epoch 20/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 34ms/step - accuracy: 0.6182 - loss: 0.0681 - val_accuracy: 0.6076 - val_loss: 0.0685 - learning_rate: 0.0010
# Epoch 21/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 30ms/step - accuracy: 0.6210 - loss: 0.0678 - val_accuracy: 0.5752 - val_loss: 0.0774 - learning_rate: 0.0010
# Epoch 22/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.6237 - loss: 0.0681 - val_accuracy: 0.5979 - val_loss: 0.0699 - learning_rate: 0.0010
# Epoch 23/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.6235 - loss: 0.0670 - val_accuracy: 0.6293 - val_loss: 0.0658 - learning_rate: 0.0010
# Epoch 24/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 30ms/step - accuracy: 0.6256 - loss: 0.0670 - val_accuracy: 0.6236 - val_loss: 0.0667 - learning_rate: 0.0010
# Epoch 25/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.6267 - loss: 0.0664 - val_accuracy: 0.6272 - val_loss: 0.0685 - learning_rate: 0.0010
# Epoch 26/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.6228 - loss: 0.0669 - val_accuracy: 0.6263 - val_loss: 0.0643 - learning_rate: 0.0010
# Epoch 27/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.6227 - loss: 0.0658 - val_accuracy: 0.6178 - val_loss: 0.0683 - learning_rate: 0.0010
# Epoch 28/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.6219 - loss: 0.0664 - val_accuracy: 0.6120 - val_loss: 0.0692 - learning_rate: 0.0010
# Epoch 29/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 35ms/step - accuracy: 0.6269 - loss: 0.0659 - val_accuracy: 0.6233 - val_loss: 0.0678 - learning_rate: 0.0010
# Epoch 30/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 30ms/step - accuracy: 0.6294 - loss: 0.0658 - val_accuracy: 0.6318 - val_loss: 0.0654 - learning_rate: 0.0010
# Epoch 31/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - accuracy: 0.6242 - loss: 0.0658 - val_accuracy: 0.5777 - val_loss: 0.0755 - learning_rate: 0.0010
# Epoch 32/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 30ms/step - accuracy: 0.6434 - loss: 0.0622 - val_accuracy: 0.6409 - val_loss: 0.0625 - learning_rate: 5.0000e-04
# Epoch 33/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.6484 - loss: 0.0610 - val_accuracy: 0.6427 - val_loss: 0.0620 - learning_rate: 5.0000e-04
# Epoch 34/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.6496 - loss: 0.0611 - val_accuracy: 0.6430 - val_loss: 0.0630 - learning_rate: 5.0000e-04
# Epoch 35/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.6471 - loss: 0.0612 - val_accuracy: 0.6365 - val_loss: 0.0639 - learning_rate: 5.0000e-04
# Epoch 36/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.6484 - loss: 0.0612 - val_accuracy: 0.6368 - val_loss: 0.0628 - learning_rate: 5.0000e-04
# Epoch 37/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.6495 - loss: 0.0612 - val_accuracy: 0.6400 - val_loss: 0.0630 - learning_rate: 5.0000e-04
# Epoch 38/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.6495 - loss: 0.0615 - val_accuracy: 0.6475 - val_loss: 0.0621 - learning_rate: 5.0000e-04
# Epoch 39/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 0.6497 - loss: 0.0602 - val_accuracy: 0.6357 - val_loss: 0.0631 - learning_rate: 2.5000e-04
# Epoch 40/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 0.6493 - loss: 0.0603 - val_accuracy: 0.6453 - val_loss: 0.0618 - learning_rate: 2.5000e-04
# Epoch 41/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 0.6524 - loss: 0.0599 - val_accuracy: 0.6514 - val_loss: 0.0616 - learning_rate: 2.5000e-04
# Epoch 42/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - accuracy: 0.6560 - loss: 0.0601 - val_accuracy: 0.6385 - val_loss: 0.0625 - learning_rate: 2.5000e-04
# Epoch 43/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.6519 - loss: 0.0600 - val_accuracy: 0.6347 - val_loss: 0.0633 - learning_rate: 2.5000e-04
# Epoch 44/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.6580 - loss: 0.0601 - val_accuracy: 0.6510 - val_loss: 0.0616 - learning_rate: 2.5000e-04
# Epoch 45/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - accuracy: 0.6515 - loss: 0.0600 - val_accuracy: 0.6453 - val_loss: 0.0623 - learning_rate: 2.5000e-04
# Epoch 46/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 30ms/step - accuracy: 0.6542 - loss: 0.0599 - val_accuracy: 0.6472 - val_loss: 0.0617 - learning_rate: 2.5000e-04
# Epoch 47/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.6562 - loss: 0.0594 - val_accuracy: 0.6465 - val_loss: 0.0621 - learning_rate: 1.2500e-04
# Epoch 48/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.6546 - loss: 0.0591 - val_accuracy: 0.6560 - val_loss: 0.0607 - learning_rate: 1.2500e-04
# Epoch 49/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.6624 - loss: 0.0592 - val_accuracy: 0.6495 - val_loss: 0.0616 - learning_rate: 1.2500e-04
# Epoch 50/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.6560 - loss: 0.0593 - val_accuracy: 0.6575 - val_loss: 0.0605 - learning_rate: 1.2500e-04
# Epoch 51/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 0.6625 - loss: 0.0590 - val_accuracy: 0.6256 - val_loss: 0.0640 - learning_rate: 1.2500e-04
# Epoch 52/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.6599 - loss: 0.0593 - val_accuracy: 0.6558 - val_loss: 0.0604 - learning_rate: 1.2500e-04
# Epoch 53/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 0.6609 - loss: 0.0587 - val_accuracy: 0.6379 - val_loss: 0.0635 - learning_rate: 1.2500e-04
# Epoch 54/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.6586 - loss: 0.0590 - val_accuracy: 0.6654 - val_loss: 0.0594 - learning_rate: 1.2500e-04
# Epoch 55/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 0.6708 - loss: 0.0585 - val_accuracy: 0.6555 - val_loss: 0.0607 - learning_rate: 1.2500e-04
# Epoch 56/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 0.6682 - loss: 0.0586 - val_accuracy: 0.6611 - val_loss: 0.0594 - learning_rate: 1.2500e-04
# Epoch 57/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 0.6601 - loss: 0.0584 - val_accuracy: 0.6501 - val_loss: 0.0609 - learning_rate: 1.2500e-04
# Epoch 58/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 0.6660 - loss: 0.0580 - val_accuracy: 0.6627 - val_loss: 0.0590 - learning_rate: 1.2500e-04
# Epoch 59/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 0.6573 - loss: 0.0586 - val_accuracy: 0.6646 - val_loss: 0.0589 - learning_rate: 1.2500e-04
# Epoch 60/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 0.6676 - loss: 0.0583 - val_accuracy: 0.6713 - val_loss: 0.0582 - learning_rate: 1.2500e-04
# Epoch 61/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 0.6707 - loss: 0.0578 - val_accuracy: 0.6080 - val_loss: 0.0701 - learning_rate: 1.2500e-04
# Epoch 62/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 0.6700 - loss: 0.0591 - val_accuracy: 0.6636 - val_loss: 0.0593 - learning_rate: 1.2500e-04
# Epoch 63/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 0.6652 - loss: 0.0577 - val_accuracy: 0.6490 - val_loss: 0.0616 - learning_rate: 1.2500e-04
# Epoch 64/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 0.6676 - loss: 0.0579 - val_accuracy: 0.6387 - val_loss: 0.0624 - learning_rate: 1.2500e-04
# Epoch 65/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 0.6690 - loss: 0.0574 - val_accuracy: 0.6739 - val_loss: 0.0574 - learning_rate: 1.2500e-04
# Epoch 66/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.6717 - loss: 0.0578 - val_accuracy: 0.6328 - val_loss: 0.0646 - learning_rate: 1.2500e-04
# Epoch 67/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 0.6748 - loss: 0.0575 - val_accuracy: 0.6459 - val_loss: 0.0615 - learning_rate: 1.2500e-04
# Epoch 68/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.6724 - loss: 0.0576 - val_accuracy: 0.6386 - val_loss: 0.0634 - learning_rate: 1.2500e-04
# Epoch 69/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 0.6747 - loss: 0.0569 - val_accuracy: 0.6376 - val_loss: 0.0623 - learning_rate: 1.2500e-04
# Epoch 70/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 0.6788 - loss: 0.0571 - val_accuracy: 0.6627 - val_loss: 0.0596 - learning_rate: 1.2500e-04
# Epoch 71/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.6848 - loss: 0.0546 - val_accuracy: 0.6730 - val_loss: 0.0572 - learning_rate: 6.2500e-05
# Epoch 72/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.6919 - loss: 0.0544 - val_accuracy: 0.6894 - val_loss: 0.0553 - learning_rate: 6.2500e-05
# Epoch 73/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 30ms/step - accuracy: 0.6865 - loss: 0.0540 - val_accuracy: 0.6580 - val_loss: 0.0597 - learning_rate: 6.2500e-05
# Epoch 74/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 32ms/step - accuracy: 0.6870 - loss: 0.0544 - val_accuracy: 0.6595 - val_loss: 0.0586 - learning_rate: 6.2500e-05
# Epoch 75/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 30ms/step - accuracy: 0.6883 - loss: 0.0540 - val_accuracy: 0.6977 - val_loss: 0.0530 - learning_rate: 6.2500e-05
# Epoch 76/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 33ms/step - accuracy: 0.6909 - loss: 0.0535 - val_accuracy: 0.7050 - val_loss: 0.0522 - learning_rate: 6.2500e-05
# Epoch 77/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 33ms/step - accuracy: 0.7028 - loss: 0.0528 - val_accuracy: 0.6904 - val_loss: 0.0543 - learning_rate: 6.2500e-05
# Epoch 78/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 35ms/step - accuracy: 0.6992 - loss: 0.0528 - val_accuracy: 0.7022 - val_loss: 0.0523 - learning_rate: 6.2500e-05
# Epoch 79/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 32ms/step - accuracy: 0.6954 - loss: 0.0530 - val_accuracy: 0.6657 - val_loss: 0.0586 - learning_rate: 6.2500e-05
# Epoch 80/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - accuracy: 0.7071 - loss: 0.0523 - val_accuracy: 0.6572 - val_loss: 0.0595 - learning_rate: 6.2500e-05
# Epoch 81/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 30ms/step - accuracy: 0.6992 - loss: 0.0522 - val_accuracy: 0.6929 - val_loss: 0.0540 - learning_rate: 6.2500e-05
# Epoch 82/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 32ms/step - accuracy: 0.7175 - loss: 0.0492 - val_accuracy: 0.7067 - val_loss: 0.0515 - learning_rate: 3.1250e-05
# Epoch 83/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.7133 - loss: 0.0494 - val_accuracy: 0.7054 - val_loss: 0.0519 - learning_rate: 3.1250e-05
# Epoch 84/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 30ms/step - accuracy: 0.7173 - loss: 0.0492 - val_accuracy: 0.7116 - val_loss: 0.0504 - learning_rate: 3.1250e-05
# Epoch 85/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.7182 - loss: 0.0491 - val_accuracy: 0.7151 - val_loss: 0.0496 - learning_rate: 3.1250e-05
# Epoch 86/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 30ms/step - accuracy: 0.7213 - loss: 0.0486 - val_accuracy: 0.6829 - val_loss: 0.0557 - learning_rate: 3.1250e-05
# Epoch 87/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 30ms/step - accuracy: 0.7176 - loss: 0.0490 - val_accuracy: 0.7182 - val_loss: 0.0491 - learning_rate: 3.1250e-05
# Epoch 88/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - accuracy: 0.7216 - loss: 0.0484 - val_accuracy: 0.7215 - val_loss: 0.0484 - learning_rate: 3.1250e-05
# Epoch 89/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 35ms/step - accuracy: 0.7220 - loss: 0.0485 - val_accuracy: 0.7212 - val_loss: 0.0486 - learning_rate: 3.1250e-05
# Epoch 90/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - accuracy: 0.7226 - loss: 0.0486 - val_accuracy: 0.7041 - val_loss: 0.0513 - learning_rate: 3.1250e-05
# Epoch 91/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 41ms/step - accuracy: 0.7242 - loss: 0.0480 - val_accuracy: 0.7166 - val_loss: 0.0498 - learning_rate: 3.1250e-05
# Epoch 92/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 41ms/step - accuracy: 0.7154 - loss: 0.0481 - val_accuracy: 0.7047 - val_loss: 0.0515 - learning_rate: 3.1250e-05
# Epoch 93/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - accuracy: 0.7247 - loss: 0.0481 - val_accuracy: 0.7147 - val_loss: 0.0493 - learning_rate: 3.1250e-05
# Epoch 94/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 30ms/step - accuracy: 0.7276 - loss: 0.0468 - val_accuracy: 0.7254 - val_loss: 0.0477 - learning_rate: 1.5625e-05
# Epoch 95/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 32ms/step - accuracy: 0.7284 - loss: 0.0468 - val_accuracy: 0.7244 - val_loss: 0.0477 - learning_rate: 1.5625e-05
# Epoch 96/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 34ms/step - accuracy: 0.7253 - loss: 0.0465 - val_accuracy: 0.7235 - val_loss: 0.0480 - learning_rate: 1.5625e-05
# Epoch 97/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 30ms/step - accuracy: 0.7247 - loss: 0.0469 - val_accuracy: 0.7260 - val_loss: 0.0477 - learning_rate: 1.5625e-05
# Epoch 98/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 30ms/step - accuracy: 0.7299 - loss: 0.0467 - val_accuracy: 0.7216 - val_loss: 0.0484 - learning_rate: 1.5625e-05
# Epoch 99/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - accuracy: 0.7361 - loss: 0.0466 - val_accuracy: 0.7192 - val_loss: 0.0480 - learning_rate: 1.5625e-05
# Epoch 100/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - accuracy: 0.7318 - loss: 0.0466 - val_accuracy: 0.7234 - val_loss: 0.0478 - learning_rate: 7.8125e-06
# Epoch 101/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 32ms/step - accuracy: 0.7294 - loss: 0.0465 - val_accuracy: 0.7268 - val_loss: 0.0475 - learning_rate: 7.8125e-06
# Epoch 102/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 30ms/step - accuracy: 0.7337 - loss: 0.0464 - val_accuracy: 0.7275 - val_loss: 0.0475 - learning_rate: 7.8125e-06
# Epoch 103/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 35ms/step - accuracy: 0.7358 - loss: 0.0464 - val_accuracy: 0.7279 - val_loss: 0.0475 - learning_rate: 7.8125e-06
# Epoch 104/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 33ms/step - accuracy: 0.7303 - loss: 0.0464 - val_accuracy: 0.7218 - val_loss: 0.0484 - learning_rate: 7.8125e-06
# Epoch 105/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.7270 - loss: 0.0464 - val_accuracy: 0.7266 - val_loss: 0.0475 - learning_rate: 7.8125e-06
# Epoch 106/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 0.7318 - loss: 0.0464 - val_accuracy: 0.7234 - val_loss: 0.0477 - learning_rate: 7.8125e-06
# Epoch 107/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.7283 - loss: 0.0465 - val_accuracy: 0.7310 - val_loss: 0.0474 - learning_rate: 3.9063e-06
# Epoch 108/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.7293 - loss: 0.0464 - val_accuracy: 0.7298 - val_loss: 0.0474 - learning_rate: 3.9063e-06
# Epoch 109/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.7317 - loss: 0.0463 - val_accuracy: 0.7289 - val_loss: 0.0473 - learning_rate: 3.9063e-06
# Epoch 110/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.7289 - loss: 0.0462 - val_accuracy: 0.7275 - val_loss: 0.0474 - learning_rate: 3.9063e-06
# Epoch 111/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.7307 - loss: 0.0465 - val_accuracy: 0.7294 - val_loss: 0.0474 - learning_rate: 3.9063e-06
# Epoch 112/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 0.7312 - loss: 0.0463 - val_accuracy: 0.7295 - val_loss: 0.0473 - learning_rate: 3.9063e-06
# Epoch 113/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.7333 - loss: 0.0462 - val_accuracy: 0.7292 - val_loss: 0.0474 - learning_rate: 1.9531e-06
# Epoch 114/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 0.7346 - loss: 0.0462 - val_accuracy: 0.7298 - val_loss: 0.0473 - learning_rate: 1.9531e-06
# Epoch 115/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 0.7346 - loss: 0.0464 - val_accuracy: 0.7292 - val_loss: 0.0473 - learning_rate: 1.9531e-06
# Epoch 116/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.7320 - loss: 0.0464 - val_accuracy: 0.7286 - val_loss: 0.0473 - learning_rate: 1.9531e-06
# Epoch 117/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.7355 - loss: 0.0461 - val_accuracy: 0.7285 - val_loss: 0.0473 - learning_rate: 1.9531e-06
# Epoch 118/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 30ms/step - accuracy: 0.7379 - loss: 0.0462 - val_accuracy: 0.7281 - val_loss: 0.0473 - learning_rate: 1.0000e-06
# Epoch 119/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 0.7315 - loss: 0.0464 - val_accuracy: 0.7298 - val_loss: 0.0473 - learning_rate: 1.0000e-06
# Epoch 120/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 30ms/step - accuracy: 0.7316 - loss: 0.0463 - val_accuracy: 0.7282 - val_loss: 0.0473 - learning_rate: 1.0000e-06
# Epoch 121/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.7339 - loss: 0.0462 - val_accuracy: 0.7295 - val_loss: 0.0473 - learning_rate: 1.0000e-06
# Epoch 122/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.7325 - loss: 0.0462 - val_accuracy: 0.7289 - val_loss: 0.0473 - learning_rate: 1.0000e-06
# Epoch 123/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.7328 - loss: 0.0463 - val_accuracy: 0.7293 - val_loss: 0.0473 - learning_rate: 1.0000e-06
# Epoch 124/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 0.7308 - loss: 0.0464 - val_accuracy: 0.7283 - val_loss: 0.0473 - learning_rate: 1.0000e-06
# Epoch 125/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 0.7344 - loss: 0.0461 - val_accuracy: 0.7291 - val_loss: 0.0473 - learning_rate: 1.0000e-06
# Epoch 126/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 0.7366 - loss: 0.0461 - val_accuracy: 0.7286 - val_loss: 0.0473 - learning_rate: 1.0000e-06
# Epoch 127/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.7356 - loss: 0.0461 - val_accuracy: 0.7285 - val_loss: 0.0473 - learning_rate: 1.0000e-06
# Epoch 128/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.7327 - loss: 0.0463 - val_accuracy: 0.7292 - val_loss: 0.0473 - learning_rate: 1.0000e-06
# Epoch 129/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 33ms/step - accuracy: 0.7322 - loss: 0.0462 - val_accuracy: 0.7297 - val_loss: 0.0473 - learning_rate: 1.0000e-06
# Epoch 130/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - accuracy: 0.7318 - loss: 0.0463 - val_accuracy: 0.7294 - val_loss: 0.0473 - learning_rate: 1.0000e-06
# Epoch 131/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.7325 - loss: 0.0461 - val_accuracy: 0.7292 - val_loss: 0.0473 - learning_rate: 1.0000e-06
# Epoch 132/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 0.7316 - loss: 0.0460 - val_accuracy: 0.7291 - val_loss: 0.0473 - learning_rate: 1.0000e-06
# Epoch 133/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.7362 - loss: 0.0461 - val_accuracy: 0.7282 - val_loss: 0.0473 - learning_rate: 1.0000e-06
# Epoch 134/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.7326 - loss: 0.0465 - val_accuracy: 0.7292 - val_loss: 0.0473 - learning_rate: 1.0000e-06
# Epoch 135/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.7346 - loss: 0.0460 - val_accuracy: 0.7272 - val_loss: 0.0474 - learning_rate: 1.0000e-06
# Epoch 136/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.7288 - loss: 0.0461 - val_accuracy: 0.7288 - val_loss: 0.0473 - learning_rate: 1.0000e-06
# Epoch 137/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.7316 - loss: 0.0461 - val_accuracy: 0.7284 - val_loss: 0.0473 - learning_rate: 1.0000e-06
# Epoch 138/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.7289 - loss: 0.0463 - val_accuracy: 0.7294 - val_loss: 0.0473 - learning_rate: 1.0000e-06
# Epoch 139/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.7293 - loss: 0.0464 - val_accuracy: 0.7291 - val_loss: 0.0473 - learning_rate: 1.0000e-06
# Epoch 140/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 32ms/step - accuracy: 0.7334 - loss: 0.0463 - val_accuracy: 0.7296 - val_loss: 0.0473 - learning_rate: 1.0000e-06
# Epoch 141/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 33ms/step - accuracy: 0.7336 - loss: 0.0462 - val_accuracy: 0.7275 - val_loss: 0.0474 - learning_rate: 1.0000e-06
# Epoch 142/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 32ms/step - accuracy: 0.7305 - loss: 0.0465 - val_accuracy: 0.7266 - val_loss: 0.0473 - learning_rate: 1.0000e-06
# Epoch 143/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - accuracy: 0.7345 - loss: 0.0461 - val_accuracy: 0.7294 - val_loss: 0.0473 - learning_rate: 1.0000e-06
# Epoch 144/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 32ms/step - accuracy: 0.7329 - loss: 0.0462 - val_accuracy: 0.7297 - val_loss: 0.0473 - learning_rate: 1.0000e-06
# Epoch 145/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 37ms/step - accuracy: 0.7321 - loss: 0.0460 - val_accuracy: 0.7297 - val_loss: 0.0473 - learning_rate: 1.0000e-06
# Epoch 146/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - accuracy: 0.7358 - loss: 0.0461 - val_accuracy: 0.7293 - val_loss: 0.0473 - learning_rate: 1.0000e-06
# Epoch 147/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 36ms/step - accuracy: 0.7335 - loss: 0.0463 - val_accuracy: 0.7286 - val_loss: 0.0473 - learning_rate: 1.0000e-06
# Epoch 148/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - accuracy: 0.7343 - loss: 0.0461 - val_accuracy: 0.7295 - val_loss: 0.0472 - learning_rate: 1.0000e-06
# Epoch 149/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 34ms/step - accuracy: 0.7316 - loss: 0.0463 - val_accuracy: 0.7304 - val_loss: 0.0472 - learning_rate: 1.0000e-06
# Epoch 150/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 33ms/step - accuracy: 0.7295 - loss: 0.0461 - val_accuracy: 0.7293 - val_loss: 0.0472 - learning_rate: 1.0000e-06
# Epoch 151/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.7325 - loss: 0.0461 - val_accuracy: 0.7297 - val_loss: 0.0472 - learning_rate: 1.0000e-06
# Epoch 152/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.7314 - loss: 0.0462 - val_accuracy: 0.7304 - val_loss: 0.0473 - learning_rate: 1.0000e-06
# Epoch 153/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 30ms/step - accuracy: 0.7309 - loss: 0.0461 - val_accuracy: 0.7288 - val_loss: 0.0473 - learning_rate: 1.0000e-06
# Epoch 154/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.7367 - loss: 0.0462 - val_accuracy: 0.7294 - val_loss: 0.0472 - learning_rate: 1.0000e-06
# Epoch 155/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 27ms/step - accuracy: 0.7333 - loss: 0.0461 - val_accuracy: 0.7305 - val_loss: 0.0472 - learning_rate: 1.0000e-06
# Epoch 156/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.7317 - loss: 0.0464 - val_accuracy: 0.7298 - val_loss: 0.0472 - learning_rate: 1.0000e-06
# Epoch 157/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.7312 - loss: 0.0461 - val_accuracy: 0.7291 - val_loss: 0.0473 - learning_rate: 1.0000e-06
# Epoch 158/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.7304 - loss: 0.0463 - val_accuracy: 0.7297 - val_loss: 0.0472 - learning_rate: 1.0000e-06
# Epoch 159/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.7311 - loss: 0.0461 - val_accuracy: 0.7293 - val_loss: 0.0472 - learning_rate: 1.0000e-06
# Epoch 160/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.7334 - loss: 0.0460 - val_accuracy: 0.7294 - val_loss: 0.0472 - learning_rate: 1.0000e-06
# Epoch 161/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.7308 - loss: 0.0462 - val_accuracy: 0.7275 - val_loss: 0.0473 - learning_rate: 1.0000e-06
# Epoch 162/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.7328 - loss: 0.0462 - val_accuracy: 0.7302 - val_loss: 0.0472 - learning_rate: 1.0000e-06
# Epoch 163/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.7307 - loss: 0.0461 - val_accuracy: 0.7294 - val_loss: 0.0472 - learning_rate: 1.0000e-06
# Epoch 164/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.7337 - loss: 0.0462 - val_accuracy: 0.7293 - val_loss: 0.0473 - learning_rate: 1.0000e-06
# Epoch 165/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.7309 - loss: 0.0462 - val_accuracy: 0.7295 - val_loss: 0.0472 - learning_rate: 1.0000e-06
# Epoch 166/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.7308 - loss: 0.0461 - val_accuracy: 0.7300 - val_loss: 0.0472 - learning_rate: 1.0000e-06
# Epoch 167/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.7311 - loss: 0.0464 - val_accuracy: 0.7294 - val_loss: 0.0472 - learning_rate: 1.0000e-06
# Epoch 168/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.7332 - loss: 0.0461 - val_accuracy: 0.7304 - val_loss: 0.0472 - learning_rate: 1.0000e-06
# Epoch 169/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.7346 - loss: 0.0462 - val_accuracy: 0.7288 - val_loss: 0.0472 - learning_rate: 1.0000e-06
# Epoch 170/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.7309 - loss: 0.0462 - val_accuracy: 0.7303 - val_loss: 0.0472 - learning_rate: 1.0000e-06
# Epoch 171/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.7318 - loss: 0.0462 - val_accuracy: 0.7285 - val_loss: 0.0473 - learning_rate: 1.0000e-06
# Epoch 172/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.7337 - loss: 0.0462 - val_accuracy: 0.7302 - val_loss: 0.0472 - learning_rate: 1.0000e-06
# Epoch 173/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.7320 - loss: 0.0460 - val_accuracy: 0.7292 - val_loss: 0.0472 - learning_rate: 1.0000e-06
# Epoch 174/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.7318 - loss: 0.0460 - val_accuracy: 0.7290 - val_loss: 0.0472 - learning_rate: 1.0000e-06
# Epoch 175/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.7323 - loss: 0.0463 - val_accuracy: 0.7280 - val_loss: 0.0473 - learning_rate: 1.0000e-06
# Epoch 176/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.7327 - loss: 0.0461 - val_accuracy: 0.7302 - val_loss: 0.0472 - learning_rate: 1.0000e-06
# Epoch 177/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 28ms/step - accuracy: 0.7282 - loss: 0.0462 - val_accuracy: 0.7294 - val_loss: 0.0472 - learning_rate: 1.0000e-06
# Epoch 178/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.7263 - loss: 0.0460 - val_accuracy: 0.7293 - val_loss: 0.0472 - learning_rate: 1.0000e-06
# Epoch 179/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 34ms/step - accuracy: 0.7323 - loss: 0.0461 - val_accuracy: 0.7301 - val_loss: 0.0472 - learning_rate: 1.0000e-06
# Epoch 180/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.7314 - loss: 0.0460 - val_accuracy: 0.7300 - val_loss: 0.0472 - learning_rate: 1.0000e-06
# Epoch 181/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.7340 - loss: 0.0462 - val_accuracy: 0.7292 - val_loss: 0.0472 - learning_rate: 1.0000e-06
# Epoch 182/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.7329 - loss: 0.0463 - val_accuracy: 0.7294 - val_loss: 0.0472 - learning_rate: 1.0000e-06
# Epoch 183/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.7306 - loss: 0.0462 - val_accuracy: 0.7300 - val_loss: 0.0472 - learning_rate: 1.0000e-06
# Epoch 184/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 32ms/step - accuracy: 0.7341 - loss: 0.0463 - val_accuracy: 0.7279 - val_loss: 0.0472 - learning_rate: 1.0000e-06
# Epoch 185/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - accuracy: 0.7297 - loss: 0.0464 - val_accuracy: 0.7289 - val_loss: 0.0472 - learning_rate: 1.0000e-06
# Epoch 186/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.7279 - loss: 0.0463 - val_accuracy: 0.7285 - val_loss: 0.0473 - learning_rate: 1.0000e-06
# Epoch 187/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 30ms/step - accuracy: 0.7323 - loss: 0.0463 - val_accuracy: 0.7294 - val_loss: 0.0472 - learning_rate: 1.0000e-06
# Epoch 188/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 3s 29ms/step - accuracy: 0.7341 - loss: 0.0465 - val_accuracy: 0.7290 - val_loss: 0.0472 - learning_rate: 1.0000e-06
# Epoch 189/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - accuracy: 0.7322 - loss: 0.0462 - val_accuracy: 0.7276 - val_loss: 0.0472 - learning_rate: 1.0000e-06
# Epoch 190/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - accuracy: 0.7335 - loss: 0.0459 - val_accuracy: 0.7303 - val_loss: 0.0472 - learning_rate: 1.0000e-06
# Epoch 191/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - accuracy: 0.7342 - loss: 0.0462 - val_accuracy: 0.7292 - val_loss: 0.0472 - learning_rate: 1.0000e-06
# Epoch 192/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 33ms/step - accuracy: 0.7333 - loss: 0.0459 - val_accuracy: 0.7294 - val_loss: 0.0472 - learning_rate: 1.0000e-06
# Epoch 193/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 36ms/step - accuracy: 0.7362 - loss: 0.0460 - val_accuracy: 0.7297 - val_loss: 0.0472 - learning_rate: 1.0000e-06
# Epoch 194/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 32ms/step - accuracy: 0.7291 - loss: 0.0461 - val_accuracy: 0.7308 - val_loss: 0.0472 - learning_rate: 1.0000e-06
# Epoch 195/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - accuracy: 0.7293 - loss: 0.0461 - val_accuracy: 0.7299 - val_loss: 0.0472 - learning_rate: 1.0000e-06
# Epoch 196/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - accuracy: 0.7367 - loss: 0.0463 - val_accuracy: 0.7278 - val_loss: 0.0473 - learning_rate: 1.0000e-06
# Epoch 197/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 32ms/step - accuracy: 0.7341 - loss: 0.0460 - val_accuracy: 0.7288 - val_loss: 0.0472 - learning_rate: 1.0000e-06
# Epoch 198/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - accuracy: 0.7300 - loss: 0.0464 - val_accuracy: 0.7295 - val_loss: 0.0472 - learning_rate: 1.0000e-06
# Epoch 199/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 30ms/step - accuracy: 0.7330 - loss: 0.0460 - val_accuracy: 0.7269 - val_loss: 0.0472 - learning_rate: 1.0000e-06
# Epoch 200/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 41ms/step - accuracy: 0.7311 - loss: 0.0463 - val_accuracy: 0.7304 - val_loss: 0.0472 - learning_rate: 1.0000e-06
# Epoch 201/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - accuracy: 0.7376 - loss: 0.0462 - val_accuracy: 0.7300 - val_loss: 0.0472 - learning_rate: 1.0000e-06
# Epoch 202/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - accuracy: 0.7362 - loss: 0.0462 - val_accuracy: 0.7303 - val_loss: 0.0472 - learning_rate: 1.0000e-06
# Epoch 203/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 32ms/step - accuracy: 0.7335 - loss: 0.0461 - val_accuracy: 0.7284 - val_loss: 0.0472 - learning_rate: 1.0000e-06
# Epoch 204/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 32ms/step - accuracy: 0.7320 - loss: 0.0461 - val_accuracy: 0.7301 - val_loss: 0.0472 - learning_rate: 1.0000e-06
# Epoch 205/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 30ms/step - accuracy: 0.7360 - loss: 0.0463 - val_accuracy: 0.7291 - val_loss: 0.0472 - learning_rate: 1.0000e-06
# Epoch 206/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - accuracy: 0.7341 - loss: 0.0459 - val_accuracy: 0.7297 - val_loss: 0.0471 - learning_rate: 1.0000e-06
# Epoch 207/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 30ms/step - accuracy: 0.7305 - loss: 0.0462 - val_accuracy: 0.7291 - val_loss: 0.0472 - learning_rate: 1.0000e-06
# Epoch 208/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 33ms/step - accuracy: 0.7352 - loss: 0.0463 - val_accuracy: 0.7289 - val_loss: 0.0472 - learning_rate: 1.0000e-06
# Epoch 209/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - accuracy: 0.7352 - loss: 0.0461 - val_accuracy: 0.7283 - val_loss: 0.0472 - learning_rate: 1.0000e-06
# Epoch 210/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - accuracy: 0.7346 - loss: 0.0462 - val_accuracy: 0.7295 - val_loss: 0.0471 - learning_rate: 1.0000e-06
# Epoch 211/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 32ms/step - accuracy: 0.7320 - loss: 0.0461 - val_accuracy: 0.7297 - val_loss: 0.0471 - learning_rate: 1.0000e-06
# Epoch 212/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - accuracy: 0.7308 - loss: 0.0464 - val_accuracy: 0.7294 - val_loss: 0.0471 - learning_rate: 1.0000e-06
# Epoch 213/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - accuracy: 0.7397 - loss: 0.0460 - val_accuracy: 0.7298 - val_loss: 0.0472 - learning_rate: 1.0000e-06
# Epoch 214/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 33ms/step - accuracy: 0.7345 - loss: 0.0461 - val_accuracy: 0.7279 - val_loss: 0.0472 - learning_rate: 1.0000e-06
# Epoch 215/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - accuracy: 0.7362 - loss: 0.0461 - val_accuracy: 0.7304 - val_loss: 0.0472 - learning_rate: 1.0000e-06
# Epoch 216/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 30ms/step - accuracy: 0.7300 - loss: 0.0463 - val_accuracy: 0.7296 - val_loss: 0.0471 - learning_rate: 1.0000e-06
# Epoch 217/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 30ms/step - accuracy: 0.7317 - loss: 0.0462 - val_accuracy: 0.7293 - val_loss: 0.0471 - learning_rate: 1.0000e-06
# Epoch 218/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 30ms/step - accuracy: 0.7337 - loss: 0.0461 - val_accuracy: 0.7278 - val_loss: 0.0473 - learning_rate: 1.0000e-06
# Epoch 219/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 30ms/step - accuracy: 0.7318 - loss: 0.0460 - val_accuracy: 0.7282 - val_loss: 0.0472 - learning_rate: 1.0000e-06
# Epoch 220/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 32ms/step - accuracy: 0.7387 - loss: 0.0461 - val_accuracy: 0.7289 - val_loss: 0.0471 - learning_rate: 1.0000e-06
# Epoch 221/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 37ms/step - accuracy: 0.7343 - loss: 0.0461 - val_accuracy: 0.7296 - val_loss: 0.0471 - learning_rate: 1.0000e-06
# Epoch 222/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 33ms/step - accuracy: 0.7306 - loss: 0.0462 - val_accuracy: 0.7293 - val_loss: 0.0471 - learning_rate: 1.0000e-06
# Epoch 223/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 32ms/step - accuracy: 0.7356 - loss: 0.0462 - val_accuracy: 0.7304 - val_loss: 0.0471 - learning_rate: 1.0000e-06
# Epoch 224/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 35ms/step - accuracy: 0.7325 - loss: 0.0461 - val_accuracy: 0.7300 - val_loss: 0.0472 - learning_rate: 1.0000e-06
# Epoch 225/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - accuracy: 0.7304 - loss: 0.0461 - val_accuracy: 0.7294 - val_loss: 0.0472 - learning_rate: 1.0000e-06
# Epoch 226/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 35ms/step - accuracy: 0.7336 - loss: 0.0460 - val_accuracy: 0.7290 - val_loss: 0.0471 - learning_rate: 1.0000e-06
# Epoch 227/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 33ms/step - accuracy: 0.7323 - loss: 0.0462 - val_accuracy: 0.7302 - val_loss: 0.0471 - learning_rate: 1.0000e-06
# Epoch 228/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 35ms/step - accuracy: 0.7306 - loss: 0.0460 - val_accuracy: 0.7300 - val_loss: 0.0471 - learning_rate: 1.0000e-06
# Epoch 229/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 34ms/step - accuracy: 0.7341 - loss: 0.0461 - val_accuracy: 0.7292 - val_loss: 0.0471 - learning_rate: 1.0000e-06
# Epoch 230/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 32ms/step - accuracy: 0.7360 - loss: 0.0460 - val_accuracy: 0.7301 - val_loss: 0.0471 - learning_rate: 1.0000e-06
# Epoch 231/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 32ms/step - accuracy: 0.7312 - loss: 0.0461 - val_accuracy: 0.7296 - val_loss: 0.0471 - learning_rate: 1.0000e-06
# Epoch 232/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 35ms/step - accuracy: 0.7318 - loss: 0.0462 - val_accuracy: 0.7303 - val_loss: 0.0471 - learning_rate: 1.0000e-06
# Epoch 233/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 38ms/step - accuracy: 0.7334 - loss: 0.0462 - val_accuracy: 0.7292 - val_loss: 0.0471 - learning_rate: 1.0000e-06
# Epoch 234/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - accuracy: 0.7310 - loss: 0.0460 - val_accuracy: 0.7307 - val_loss: 0.0471 - learning_rate: 1.0000e-06
# Epoch 235/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 36ms/step - accuracy: 0.7323 - loss: 0.0461 - val_accuracy: 0.7303 - val_loss: 0.0471 - learning_rate: 1.0000e-06
# Epoch 236/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 40ms/step - accuracy: 0.7347 - loss: 0.0462 - val_accuracy: 0.7301 - val_loss: 0.0471 - learning_rate: 1.0000e-06
# Epoch 237/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 33ms/step - accuracy: 0.7348 - loss: 0.0459 - val_accuracy: 0.7293 - val_loss: 0.0471 - learning_rate: 1.0000e-06
# Epoch 238/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 32ms/step - accuracy: 0.7332 - loss: 0.0462 - val_accuracy: 0.7298 - val_loss: 0.0471 - learning_rate: 1.0000e-06
# Epoch 239/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - accuracy: 0.7366 - loss: 0.0461 - val_accuracy: 0.7298 - val_loss: 0.0471 - learning_rate: 1.0000e-06
# Epoch 240/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 32ms/step - accuracy: 0.7328 - loss: 0.0462 - val_accuracy: 0.7296 - val_loss: 0.0471 - learning_rate: 1.0000e-06
# Epoch 241/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 32ms/step - accuracy: 0.7319 - loss: 0.0462 - val_accuracy: 0.7300 - val_loss: 0.0471 - learning_rate: 1.0000e-06
# Epoch 242/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 35ms/step - accuracy: 0.7339 - loss: 0.0460 - val_accuracy: 0.7298 - val_loss: 0.0471 - learning_rate: 1.0000e-06
# Epoch 243/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 34ms/step - accuracy: 0.7282 - loss: 0.0462 - val_accuracy: 0.7295 - val_loss: 0.0471 - learning_rate: 1.0000e-06
# Epoch 244/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 33ms/step - accuracy: 0.7303 - loss: 0.0460 - val_accuracy: 0.7296 - val_loss: 0.0471 - learning_rate: 1.0000e-06
# Epoch 245/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 33ms/step - accuracy: 0.7317 - loss: 0.0459 - val_accuracy: 0.7298 - val_loss: 0.0471 - learning_rate: 1.0000e-06
# Epoch 246/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 30ms/step - accuracy: 0.7338 - loss: 0.0461 - val_accuracy: 0.7287 - val_loss: 0.0471 - learning_rate: 1.0000e-06
# Epoch 247/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - accuracy: 0.7293 - loss: 0.0462 - val_accuracy: 0.7290 - val_loss: 0.0471 - learning_rate: 1.0000e-06
# Epoch 248/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 32ms/step - accuracy: 0.7358 - loss: 0.0461 - val_accuracy: 0.7296 - val_loss: 0.0471 - learning_rate: 1.0000e-06
# Epoch 249/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - accuracy: 0.7296 - loss: 0.0462 - val_accuracy: 0.7295 - val_loss: 0.0471 - learning_rate: 1.0000e-06
# Epoch 250/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 32ms/step - accuracy: 0.7349 - loss: 0.0464 - val_accuracy: 0.7290 - val_loss: 0.0471 - learning_rate: 1.0000e-06
# Epoch 251/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 32ms/step - accuracy: 0.7386 - loss: 0.0461 - val_accuracy: 0.7294 - val_loss: 0.0471 - learning_rate: 1.0000e-06
# Epoch 252/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 32ms/step - accuracy: 0.7345 - loss: 0.0459 - val_accuracy: 0.7303 - val_loss: 0.0471 - learning_rate: 1.0000e-06
# Epoch 253/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 38ms/step - accuracy: 0.7327 - loss: 0.0462 - val_accuracy: 0.7303 - val_loss: 0.0471 - learning_rate: 1.0000e-06
# Epoch 254/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 32ms/step - accuracy: 0.7329 - loss: 0.0458 - val_accuracy: 0.7283 - val_loss: 0.0471 - learning_rate: 1.0000e-06
# Epoch 255/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 35ms/step - accuracy: 0.7369 - loss: 0.0460 - val_accuracy: 0.7286 - val_loss: 0.0471 - learning_rate: 1.0000e-06
# Epoch 256/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 32ms/step - accuracy: 0.7329 - loss: 0.0460 - val_accuracy: 0.7295 - val_loss: 0.0471 - learning_rate: 1.0000e-06
# Epoch 257/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 33ms/step - accuracy: 0.7347 - loss: 0.0462 - val_accuracy: 0.7292 - val_loss: 0.0471 - learning_rate: 1.0000e-06
# Epoch 258/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - accuracy: 0.7291 - loss: 0.0463 - val_accuracy: 0.7303 - val_loss: 0.0471 - learning_rate: 1.0000e-06
# Epoch 259/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 32ms/step - accuracy: 0.7310 - loss: 0.0461 - val_accuracy: 0.7301 - val_loss: 0.0471 - learning_rate: 1.0000e-06
# Epoch 260/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 34ms/step - accuracy: 0.7300 - loss: 0.0462 - val_accuracy: 0.7303 - val_loss: 0.0471 - learning_rate: 1.0000e-06
# Epoch 261/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 32ms/step - accuracy: 0.7339 - loss: 0.0461 - val_accuracy: 0.7304 - val_loss: 0.0471 - learning_rate: 1.0000e-06
# Epoch 262/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - accuracy: 0.7290 - loss: 0.0461 - val_accuracy: 0.7296 - val_loss: 0.0471 - learning_rate: 1.0000e-06
# Epoch 263/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - accuracy: 0.7326 - loss: 0.0461 - val_accuracy: 0.7294 - val_loss: 0.0471 - learning_rate: 1.0000e-06
# Epoch 264/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 32ms/step - accuracy: 0.7341 - loss: 0.0461 - val_accuracy: 0.7301 - val_loss: 0.0471 - learning_rate: 1.0000e-06
# Epoch 265/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 36ms/step - accuracy: 0.7317 - loss: 0.0463 - val_accuracy: 0.7299 - val_loss: 0.0471 - learning_rate: 1.0000e-06
# Epoch 266/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 33ms/step - accuracy: 0.7322 - loss: 0.0460 - val_accuracy: 0.7297 - val_loss: 0.0471 - learning_rate: 1.0000e-06
# Epoch 267/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 32ms/step - accuracy: 0.7324 - loss: 0.0463 - val_accuracy: 0.7293 - val_loss: 0.0471 - learning_rate: 1.0000e-06
# Epoch 268/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 5s 39ms/step - accuracy: 0.7266 - loss: 0.0460 - val_accuracy: 0.7295 - val_loss: 0.0471 - learning_rate: 1.0000e-06
# Epoch 269/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - accuracy: 0.7293 - loss: 0.0461 - val_accuracy: 0.7286 - val_loss: 0.0472 - learning_rate: 1.0000e-06
# Epoch 270/300
# 118/118 ━━━━━━━━━━━━━━━━━━━━ 4s 31ms/step - accuracy: 0.7316 - loss: 0.0461 - val_accuracy: 0.7306 - val_loss: 0.0471 - learning_rate: 1.0000e-06
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7252 - loss: 0.0468
# Test loss: 0.04690365120768547
# Test accuracy: 0.7300999760627747

# %%
history.history['test_accuracy'] = [test_accuracy] * len(history.history['accuracy'])
history.history['test_loss'] = [test_loss] * len(history.history['loss'])

# Plot loss and accuracy
plt.figure(figsize=(14, 5))

plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train')
plt.plot(history.history['val_accuracy'], label='Validation')
plt.plot(history.history['test_accuracy'], label='Test')
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train')
plt.plot(history.history['val_loss'], label='Validation')
plt.plot(history.history['test_loss'], label='Test')
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend()

plt.show()

# %%
# Make predictions
y_pred = model.predict(X_test_scaled)
print(f'Prediction shape: {y_pred.shape}')

# Reshape the predicted outputs to match the original shape
# y_pred_rescaled = y_pred.reshape(-1, y_pred.shape[-1])

# Inverse transform the predicted outputs
y_pred_original_scale = y_scaler.inverse_transform(y_pred).reshape(y_pred.shape)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# Prediction shape: (10000, 10)

# %%
# Select a random index for a 5x10 segment
random_index = np.random.randint(0, len(y_test))
actual_segment = y_test[random_index]
predicted_segment = y_pred_original_scale[random_index]

# %%
# Select a random index for a 5x10 segment
random_index = np.random.randint(0, len(y_test))
actual_segment = y_test[random_index]
predicted_segment = y_pred_original_scale[random_index]

x = range(1, 11)


plt.figure(figsize=(14, 10))
plt.plot(x, actual_segment, 'b.-', label='Actual Temperature')
plt.plot(x, predicted_segment, 'r.-', label='Predicted Temperature')

plt.xlabel('Layer')
plt.ylabel('Temperature')
plt.xticks(np.arange(1, 11, step=1))

plt.title(f"Actual vs Predicted Temperatures on Sample {random_index} for First Time Interval")
plt.legend()
plt.grid(True)
plt.show()

# %%
# Calculate absolute difference
temp_diff_abs = np.abs(y_test - y_pred_original_scale)

# %%
# Sum columns together and find mean
avg_temp_diff = np.sum(temp_diff_abs, axis=0) / 10000

# %%
avg_temp_diff
# Out:
# array([2.93627247, 6.24445304, 6.4387578 , 5.4848922 , 5.94231649,
#        5.99235633, 4.52579205, 2.50722205, 0.97279785, 0.3232259 ])

# %%
plt.figure(figsize=(16, 10))

# Plot horizontal bar graph
bars = plt.barh(x, avg_temp_diff, color='orange')

# Set the x-axis limits if needed
plt.xlim(math.floor(np.min(avg_temp_diff)), math.ceil(np.max(avg_temp_diff)) + 1)

# Add title and labels
plt.title("Average Absolute Temperature Difference in Feed-Forward model")
plt.ylabel("Layer")
plt.xlabel("Absolute Temperature Difference (K)")

# Set y-ticks for layers
plt.yticks(np.arange(1, 11, step=1))

# Set x-ticks for temperature difference
plt.xticks(np.arange(math.floor(np.min(avg_temp_diff)), math.ceil(np.max(avg_temp_diff)) + 1, step=1))

# Add labels to each bar
for bar in bars:
    width = bar.get_width()
    plt.text(width + 0.1, bar.get_y() + bar.get_height() / 2, f'{width:.2f}', 
             ha='left', va='center')

plt.show()

# %% [markdown]
# # Hyperparameter Tuning

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Input
from tensorflow.keras.optimizers import Nadam, Adam, RMSprop
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
import kerastuner as kt

# Define a function to build the model
def build_model(hp):
    model = Sequential()
    model.add(Input(shape=spectra_row_reshape[1].shape))

    # Hyperparameter for number of dense layers
    for i in range(hp.Int('num_layers', 2, 9)):
        model.add(Dense(units=hp.Int(f'units_{i}', min_value=32, max_value=2048, step=32),
                        activation=hp.Choice('activation', ['relu', 'tanh', 'sigmoid'])))

    model.add(Dense(10, activation='linear'))

    # Choose the optimizer
    optimizer = hp.Choice('optimizer', ['nadam', 'adam', 'rmsprop'])
    if optimizer == 'nadam':
        optimizer = Nadam(learning_rate=hp.Choice('learning_rate', [1e-2, 1e-3, 1e-4]))
    elif optimizer == 'adam':
        optimizer = Adam(learning_rate=hp.Choice('learning_rate', [1e-2, 1e-3, 1e-4]))
    else:
        optimizer = RMSprop(learning_rate=hp.Choice('learning_rate', [1e-2, 1e-3, 1e-4]))

    model.compile(optimizer=optimizer, loss='mae', metrics=['accuracy'])
    return model

# Set up hyperparameter tuner
tuner = kt.Hyperband(
    build_model,
    objective='val_loss',
    max_epochs=50,
    factor=3,
    directory='hyperband',
    project_name='hyperparameter_tuning'
)

# Define early stopping and learning rate reduction
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-6)

# Run the tuner search
tuner.search(
    X_train_scaled, y_train_scaled,
    epochs=200,
    batch_size=hp.Choice('batch_size', [32, 64, 128, 256]),
    validation_data=(X_val_scaled, y_val_scaled),
    callbacks=[early_stopping, reduce_lr]
)

# Get the optimal hyperparameters
best_hps = tuner.get_best_hyperparameters(num_trials=1)[0]
print(f"""
The hyperparameter search is complete. The optimal number of units in the first densely-connected
layer is {best_hps.get('units_0')} and the optimal activation function is {best_hps.get('activation')}.
The optimal learning rate for the optimizer is {best_hps.get('learning_rate')}.
""")

# Build the model with the optimal hyperparameters and train it
model = tuner.hypermodel.build(best_hps)
history = model.fit(
    X_train_scaled, y_train_scaled,
    epochs=200,
    batch_size=best_hps.get('batch_size'),
    validation_data=(X_val_scaled, y_val_scaled),
    callbacks=[early_stopping, reduce_lr]
)

# Evaluate the model on the test set
test_loss, test_accuracy = model.evaluate(X_test_scaled, y_test_scaled)
print(f'Test loss: {test_loss}')
print(f'Test accuracy: {test_accuracy}')
# Out:
# /var/folders/h9/27j9s9d17bs9wzh9ygj50dzc0000gn/T/ipykernel_9332/1554486872.py:6: DeprecationWarning: `import kerastuner` is deprecated, please use `import keras_tuner`.
#   import kerastuner as kt
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[57], line 50
#      44 reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-6)
#      46 # Run the tuner search
#      47 tuner.search(
#      48     X_train_scaled, y_train_scaled,
#      49     epochs=200,
# ---> 50     batch_size=hp.Choice('batch_size', [32, 64, 128, 256]),
#      51     validation_data=(X_val_scaled, y_val_scaled),
#      52     callbacks=[early_stopping, reduce_lr]
#      53 )
#      55 # Get the optimal hyperparameters
#      56 best_hps = tuner.get_best_hyperparameters(num_trials=1)[0]
#
# NameError: name 'hp' is not defined
