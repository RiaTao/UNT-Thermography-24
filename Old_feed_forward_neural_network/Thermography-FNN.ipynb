# %%
import scipy.io
from scipy.stats import bootstrap
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, BatchNormalization, Input, LeakyReLU
from tensorflow.keras.optimizers import AdamW, RMSprop
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.initializers import he_normal
from tensorflow.keras.regularizers import L1, L2
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import RobustScaler, PolynomialFeatures, StandardScaler, normalize, MinMaxScaler
from sklearn.decomposition import PCA
import math
import matplotlib.pyplot as plt
from scikeras.wrappers import KerasClassifier, KerasRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.datasets import make_classification

# Load .mat file
mat = scipy.io.loadmat('../UNT-Thermography-24/fused_silica_data/data_GaN_8_15micron_1.mat')

# Extract and reshape data
Temp_all = mat.get('T_GaN_random')
Spectra_all = mat.get('Spectrum')

temp_T = Temp_all.transpose(2, 0, 1)
spectra_T = Spectra_all.transpose(2, 0, 1)

temp_row = temp_T[:, 0, :]
spectra_row = spectra_T[:, 0, :]


temp_line = Temp_all.reshape(2000, 50)
spectra_line = Spectra_all.reshape(2000, 355)




# Create pandas DataFrame
pd_spectra = pd.DataFrame(spectra_line)
pd_temp = pd.DataFrame(temp_line)

# Select the data
X = pd_spectra.iloc[0:2000]
Y = pd_temp.iloc[0:2000]

# X_min = np.min(X)
# X_max = np.max(X)

# X_denom = X_max - X_min
# X_numer = X - X_min

# X_normal = X_numer/X_denom


# Y_min = np.min(Y)
# Y_max = np.max(Y)

# Y_denom = Y_max - Y_min
# Y_numer = Y - Y_min

# Y_normal = Y_numer/Y_denom

scalerX, scalerY = MinMaxScaler(), MinMaxScaler()
X_scaled = scalerX.fit_transform(X)
Y_scaled = scalerY.fit_transform(Y)

# X_scaled = pd.DataFrame(X_scaled)
# Y_scaled = pd.DataFrame(Y_scaled)

# X_normal = normalize(X)

# X = -np.log(X)

# Scale the features using RobustScaler
# scaler = StandardScaler()
# X_scaled = scaler.fit_transform(X)

# # Create polynomial features
# poly = PolynomialFeatures(degree=2, include_bias=True)
# X_poly = poly.fit_transform(X_normal)

# # Apply PCA for dimensionality reduction
# pca = PCA(n_components=50)  # Adjust n_components based on variance explained
# X_pca = pca.fit_transform(X_poly)

# # Split the data
X_train, X_test, y_train, y_test = train_test_split(X_scaled, Y_scaled, test_size=0.20, random_state=30)
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.20, random_state=30)



# y_train_normal = (y_train - Y_min) / (Y_denom)
# y_test_normal = (y_test - Y_min) / (Y_denom)
# y_val_normal = (y_val - Y_min) / (Y_denom)

# X_train_normal = normalize(X_train, norm="l1")
# X_val_normal = normalize(X_val, norm="l1")
# X_test_normal = normalize(X_test, norm="l1")

# %%
import numpy as np
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import Dense, Input, BatchNormalization, Dropout
from keras.optimizers import RMSprop, Adam, SGD, AdamW, Adagrad
from keras.regularizers import l2
from keras.layers import LeakyReLU

# Define the model
model = Sequential()
model.add(Input(shape=(X_train.shape[1],)))

# Uncomment the following block if you want to add layers in a loop
# for i in range(100): 
#     model.add(Dense(30, activation=LeakyReLU()))
#     model.add(BatchNormalization())
#     # model.add(Dropout(0.3))

for _ in range(3):
    model.add(Dense(256, activation='leaky_relu'))
    # model.add(BatchNormalization())
    # model.add(Dropout(0.2))
for _ in range(4):
    model.add(Dense(128, activation='leaky_relu'))

for _ in range(3):
    model.add(Dense(64, activation='leaky_relu'))

# for _ in range(30):
#     model.add(Dense(30, activation='leaky_relu', kernel_regularizer=l2(.00001)))

model.add(Dense(50, activation='relu'))


# Compile the model
rprop = RMSprop(learning_rate=0.001)
adam = AdamW(learning_rate=0.001)
sgd = SGD(learning_rate=0.0001)
ada = Adagrad(learning_rate=.001)
model.compile(optimizer=ada, loss='mse', metrics=['mae'])

early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, min_lr=1e-6)
# Train the model
history = model.fit(X_train, y_train, epochs=300, batch_size=32, validation_data=(X_val, y_val))#, 
                    # callbacks=[early_stopping, reduce_lr])


model.save('temperature_prediction.keras')
# Print training metrics
print(f"train_MSE: {history.history['loss'][-1]}")
print(f"train_MAE: {history.history['mae'][-1]}")

# Evaluate the model on the validation set
validation_loss, validation_mae = model.evaluate(X_val, y_val)
print(f"val_MSE: {validation_loss}, val_MAE: {validation_mae}")

# Evaluate the model on the test set
test_loss, test_mae = model.evaluate(X_test, y_test)
print(f"test_MSE: {test_loss}, test_MAE: {test_mae}")

# Add test metrics to the history for plotting
history.history['test_loss'] = [test_loss] * len(history.history['loss'])
history.history['test_mae'] = [test_mae] * len(history.history['mae'])

# Plot training, validation, and test loss and mae values
plt.figure(figsize=(14, 6))

# Plot training and validation loss
plt.subplot(1, 2, 1)
plt.plot(history.history["loss"], label='Training Loss')
plt.plot(history.history["val_loss"], label='Validation Loss')
plt.plot(history.history["test_loss"], label='Test Loss')
plt.title('Training, Validation, and Testing Loss over Epochs')
plt.xlabel('Epochs')
plt.ylabel('Loss (MSE)')
plt.legend()
plt.grid(True)

# Plot training and validation MAE
plt.subplot(1, 2, 2)
plt.plot(history.history["mae"], label="Training MAE")
plt.plot(history.history["val_mae"], label="Validation MAE")
plt.plot(history.history["test_mae"], label="Test MAE")
plt.title('Training, Validation, and Testing MAE over Epochs')
plt.xlabel('Epochs')
plt.ylabel('MAE')
plt.legend()
plt.grid(True)

plt.show()
# Out:
# Epoch 1/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.1637 - mae: 0.3716 - val_loss: 0.1674 - val_mae: 0.3778
# Epoch 2/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1620 - mae: 0.3696 - val_loss: 0.1631 - val_mae: 0.3715
# Epoch 3/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1570 - mae: 0.3610 - val_loss: 0.1591 - val_mae: 0.3654
# Epoch 4/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1505 - mae: 0.3530 - val_loss: 0.1551 - val_mae: 0.3594
# Epoch 5/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1481 - mae: 0.3487 - val_loss: 0.1513 - val_mae: 0.3534
# Epoch 6/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1460 - mae: 0.3442 - val_loss: 0.1474 - val_mae: 0.3474
# Epoch 7/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1386 - mae: 0.3343 - val_loss: 0.1435 - val_mae: 0.3412
# Epoch 8/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1347 - mae: 0.3266 - val_loss: 0.1395 - val_mae: 0.3349
# Epoch 9/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1368 - mae: 0.3296 - val_loss: 0.1356 - val_mae: 0.3286
# Epoch 10/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1287 - mae: 0.3176 - val_loss: 0.1319 - val_mae: 0.3226
# Epoch 11/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1221 - mae: 0.3050 - val_loss: 0.1284 - val_mae: 0.3169
# Epoch 12/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1215 - mae: 0.3054 - val_loss: 0.1250 - val_mae: 0.3114
# Epoch 13/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1208 - mae: 0.3042 - val_loss: 0.1218 - val_mae: 0.3062
# Epoch 14/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1174 - mae: 0.3000 - val_loss: 0.1188 - val_mae: 0.3014
# Epoch 15/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1137 - mae: 0.2932 - val_loss: 0.1160 - val_mae: 0.2968
# Epoch 16/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1122 - mae: 0.2914 - val_loss: 0.1134 - val_mae: 0.2924
# Epoch 17/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1093 - mae: 0.2857 - val_loss: 0.1109 - val_mae: 0.2884
# Epoch 18/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1072 - mae: 0.2813 - val_loss: 0.1086 - val_mae: 0.2846
# Epoch 19/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1041 - mae: 0.2773 - val_loss: 0.1065 - val_mae: 0.2810
# Epoch 20/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1022 - mae: 0.2730 - val_loss: 0.1044 - val_mae: 0.2775
# Epoch 21/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0970 - mae: 0.2654 - val_loss: 0.1025 - val_mae: 0.2743
# Epoch 22/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0988 - mae: 0.2688 - val_loss: 0.1007 - val_mae: 0.2713
# Epoch 23/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0984 - mae: 0.2677 - val_loss: 0.0990 - val_mae: 0.2684
# Epoch 24/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0930 - mae: 0.2591 - val_loss: 0.0974 - val_mae: 0.2658
# Epoch 25/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0931 - mae: 0.2595 - val_loss: 0.0959 - val_mae: 0.2633
# Epoch 26/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0924 - mae: 0.2578 - val_loss: 0.0944 - val_mae: 0.2609
# Epoch 27/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0924 - mae: 0.2572 - val_loss: 0.0931 - val_mae: 0.2586
# Epoch 28/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0900 - mae: 0.2541 - val_loss: 0.0918 - val_mae: 0.2565
# Epoch 29/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0901 - mae: 0.2537 - val_loss: 0.0905 - val_mae: 0.2544
# Epoch 30/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0861 - mae: 0.2475 - val_loss: 0.0892 - val_mae: 0.2522
# Epoch 31/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0839 - mae: 0.2435 - val_loss: 0.0878 - val_mae: 0.2500
# Epoch 32/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0842 - mae: 0.2450 - val_loss: 0.0865 - val_mae: 0.2479
# Epoch 33/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0844 - mae: 0.2456 - val_loss: 0.0852 - val_mae: 0.2458
# Epoch 34/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0837 - mae: 0.2438 - val_loss: 0.0840 - val_mae: 0.2437
# Epoch 35/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0816 - mae: 0.2407 - val_loss: 0.0828 - val_mae: 0.2418
# Epoch 36/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0802 - mae: 0.2377 - val_loss: 0.0816 - val_mae: 0.2398
# Epoch 37/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0777 - mae: 0.2339 - val_loss: 0.0805 - val_mae: 0.2380
# Epoch 38/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0796 - mae: 0.2362 - val_loss: 0.0795 - val_mae: 0.2362
# Epoch 39/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0757 - mae: 0.2306 - val_loss: 0.0785 - val_mae: 0.2344
# Epoch 40/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0772 - mae: 0.2328 - val_loss: 0.0776 - val_mae: 0.2327
# Epoch 41/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0770 - mae: 0.2329 - val_loss: 0.0766 - val_mae: 0.2311
# Epoch 42/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0748 - mae: 0.2284 - val_loss: 0.0757 - val_mae: 0.2294
# Epoch 43/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0724 - mae: 0.2256 - val_loss: 0.0749 - val_mae: 0.2278
# Epoch 44/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0730 - mae: 0.2249 - val_loss: 0.0741 - val_mae: 0.2263
# Epoch 45/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0707 - mae: 0.2208 - val_loss: 0.0733 - val_mae: 0.2248
# Epoch 46/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0740 - mae: 0.2264 - val_loss: 0.0725 - val_mae: 0.2233
# Epoch 47/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0712 - mae: 0.2220 - val_loss: 0.0717 - val_mae: 0.2218
# Epoch 48/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0700 - mae: 0.2199 - val_loss: 0.0710 - val_mae: 0.2204
# Epoch 49/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0699 - mae: 0.2195 - val_loss: 0.0703 - val_mae: 0.2191
# Epoch 50/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0699 - mae: 0.2198 - val_loss: 0.0697 - val_mae: 0.2177
# Epoch 51/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0686 - mae: 0.2170 - val_loss: 0.0690 - val_mae: 0.2164
# Epoch 52/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0664 - mae: 0.2132 - val_loss: 0.0684 - val_mae: 0.2152
# Epoch 53/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0668 - mae: 0.2130 - val_loss: 0.0679 - val_mae: 0.2140
# Epoch 54/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0669 - mae: 0.2135 - val_loss: 0.0673 - val_mae: 0.2128
# Epoch 55/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0657 - mae: 0.2119 - val_loss: 0.0668 - val_mae: 0.2116
# Epoch 56/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0650 - mae: 0.2104 - val_loss: 0.0663 - val_mae: 0.2105
# Epoch 57/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0644 - mae: 0.2081 - val_loss: 0.0658 - val_mae: 0.2094
# Epoch 58/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0638 - mae: 0.2070 - val_loss: 0.0653 - val_mae: 0.2083
# Epoch 59/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0637 - mae: 0.2074 - val_loss: 0.0648 - val_mae: 0.2072
# Epoch 60/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0639 - mae: 0.2065 - val_loss: 0.0644 - val_mae: 0.2062
# Epoch 61/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0632 - mae: 0.2058 - val_loss: 0.0640 - val_mae: 0.2052
# Epoch 62/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0613 - mae: 0.2022 - val_loss: 0.0636 - val_mae: 0.2042
# Epoch 63/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0613 - mae: 0.2019 - val_loss: 0.0632 - val_mae: 0.2032
# Epoch 64/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0614 - mae: 0.2020 - val_loss: 0.0628 - val_mae: 0.2023
# Epoch 65/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0612 - mae: 0.2018 - val_loss: 0.0624 - val_mae: 0.2013
# Epoch 66/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0603 - mae: 0.1993 - val_loss: 0.0621 - val_mae: 0.2004
# Epoch 67/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0606 - mae: 0.2002 - val_loss: 0.0618 - val_mae: 0.1995
# Epoch 68/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0599 - mae: 0.1981 - val_loss: 0.0614 - val_mae: 0.1987
# Epoch 69/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0598 - mae: 0.1973 - val_loss: 0.0611 - val_mae: 0.1979
# Epoch 70/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0595 - mae: 0.1967 - val_loss: 0.0608 - val_mae: 0.1970
# Epoch 71/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0580 - mae: 0.1944 - val_loss: 0.0605 - val_mae: 0.1962
# Epoch 72/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0596 - mae: 0.1960 - val_loss: 0.0603 - val_mae: 0.1954
# Epoch 73/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0587 - mae: 0.1946 - val_loss: 0.0600 - val_mae: 0.1947
# Epoch 74/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0598 - mae: 0.1962 - val_loss: 0.0598 - val_mae: 0.1939
# Epoch 75/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0580 - mae: 0.1938 - val_loss: 0.0595 - val_mae: 0.1932
# Epoch 76/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0582 - mae: 0.1929 - val_loss: 0.0593 - val_mae: 0.1925
# Epoch 77/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0575 - mae: 0.1907 - val_loss: 0.0591 - val_mae: 0.1918
# Epoch 78/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0580 - mae: 0.1931 - val_loss: 0.0589 - val_mae: 0.1911
# Epoch 79/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0574 - mae: 0.1907 - val_loss: 0.0586 - val_mae: 0.1904
# Epoch 80/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0574 - mae: 0.1901 - val_loss: 0.0585 - val_mae: 0.1898
# Epoch 81/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0567 - mae: 0.1869 - val_loss: 0.0583 - val_mae: 0.1892
# Epoch 82/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0570 - mae: 0.1888 - val_loss: 0.0581 - val_mae: 0.1886
# Epoch 83/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0564 - mae: 0.1889 - val_loss: 0.0579 - val_mae: 0.1880
# Epoch 84/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0570 - mae: 0.1891 - val_loss: 0.0578 - val_mae: 0.1874
# Epoch 85/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0578 - mae: 0.1899 - val_loss: 0.0576 - val_mae: 0.1869
# Epoch 86/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0572 - mae: 0.1875 - val_loss: 0.0574 - val_mae: 0.1864
# Epoch 87/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0562 - mae: 0.1853 - val_loss: 0.0573 - val_mae: 0.1858
# Epoch 88/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0571 - mae: 0.1878 - val_loss: 0.0572 - val_mae: 0.1853
# Epoch 89/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0561 - mae: 0.1854 - val_loss: 0.0570 - val_mae: 0.1848
# Epoch 90/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0566 - mae: 0.1844 - val_loss: 0.0569 - val_mae: 0.1844
# Epoch 91/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0555 - mae: 0.1848 - val_loss: 0.0568 - val_mae: 0.1839
# Epoch 92/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0550 - mae: 0.1836 - val_loss: 0.0567 - val_mae: 0.1834
# Epoch 93/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0550 - mae: 0.1813 - val_loss: 0.0565 - val_mae: 0.1830
# Epoch 94/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0554 - mae: 0.1831 - val_loss: 0.0564 - val_mae: 0.1825
# Epoch 95/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0563 - mae: 0.1845 - val_loss: 0.0563 - val_mae: 0.1821
# Epoch 96/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0556 - mae: 0.1824 - val_loss: 0.0562 - val_mae: 0.1817
# Epoch 97/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0560 - mae: 0.1835 - val_loss: 0.0561 - val_mae: 0.1813
# Epoch 98/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0546 - mae: 0.1802 - val_loss: 0.0560 - val_mae: 0.1809
# Epoch 99/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0551 - mae: 0.1812 - val_loss: 0.0560 - val_mae: 0.1805
# Epoch 100/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0556 - mae: 0.1809 - val_loss: 0.0559 - val_mae: 0.1802
# Epoch 101/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0548 - mae: 0.1800 - val_loss: 0.0558 - val_mae: 0.1798
# Epoch 102/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0542 - mae: 0.1786 - val_loss: 0.0557 - val_mae: 0.1795
# Epoch 103/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0552 - mae: 0.1812 - val_loss: 0.0556 - val_mae: 0.1792
# Epoch 104/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0543 - mae: 0.1784 - val_loss: 0.0556 - val_mae: 0.1789
# Epoch 105/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0546 - mae: 0.1786 - val_loss: 0.0555 - val_mae: 0.1786
# Epoch 106/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0545 - mae: 0.1795 - val_loss: 0.0554 - val_mae: 0.1782
# Epoch 107/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0556 - mae: 0.1811 - val_loss: 0.0554 - val_mae: 0.1779
# Epoch 108/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0540 - mae: 0.1772 - val_loss: 0.0553 - val_mae: 0.1777
# Epoch 109/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0533 - mae: 0.1769 - val_loss: 0.0552 - val_mae: 0.1774
# Epoch 110/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0527 - mae: 0.1739 - val_loss: 0.0552 - val_mae: 0.1771
# Epoch 111/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0536 - mae: 0.1760 - val_loss: 0.0551 - val_mae: 0.1768
# Epoch 112/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0544 - mae: 0.1773 - val_loss: 0.0551 - val_mae: 0.1766
# Epoch 113/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0553 - mae: 0.1787 - val_loss: 0.0550 - val_mae: 0.1764
# Epoch 114/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0543 - mae: 0.1763 - val_loss: 0.0550 - val_mae: 0.1761
# Epoch 115/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0536 - mae: 0.1745 - val_loss: 0.0549 - val_mae: 0.1759
# Epoch 116/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0548 - mae: 0.1767 - val_loss: 0.0549 - val_mae: 0.1757
# Epoch 117/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0542 - mae: 0.1776 - val_loss: 0.0549 - val_mae: 0.1755
# Epoch 118/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0543 - mae: 0.1758 - val_loss: 0.0548 - val_mae: 0.1753
# Epoch 119/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0549 - mae: 0.1776 - val_loss: 0.0548 - val_mae: 0.1751
# Epoch 120/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0533 - mae: 0.1743 - val_loss: 0.0547 - val_mae: 0.1748
# Epoch 121/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0532 - mae: 0.1741 - val_loss: 0.0547 - val_mae: 0.1746
# Epoch 122/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0539 - mae: 0.1743 - val_loss: 0.0547 - val_mae: 0.1744
# Epoch 123/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0531 - mae: 0.1733 - val_loss: 0.0546 - val_mae: 0.1742
# Epoch 124/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0541 - mae: 0.1752 - val_loss: 0.0546 - val_mae: 0.1741
# Epoch 125/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0533 - mae: 0.1738 - val_loss: 0.0545 - val_mae: 0.1739
# Epoch 126/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0522 - mae: 0.1704 - val_loss: 0.0545 - val_mae: 0.1737
# Epoch 127/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0543 - mae: 0.1757 - val_loss: 0.0545 - val_mae: 0.1735
# Epoch 128/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0532 - mae: 0.1732 - val_loss: 0.0544 - val_mae: 0.1733
# Epoch 129/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0536 - mae: 0.1734 - val_loss: 0.0544 - val_mae: 0.1732
# Epoch 130/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0529 - mae: 0.1730 - val_loss: 0.0544 - val_mae: 0.1730
# Epoch 131/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0526 - mae: 0.1715 - val_loss: 0.0544 - val_mae: 0.1729
# Epoch 132/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0534 - mae: 0.1718 - val_loss: 0.0543 - val_mae: 0.1727
# Epoch 133/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0536 - mae: 0.1733 - val_loss: 0.0543 - val_mae: 0.1726
# Epoch 134/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0527 - mae: 0.1721 - val_loss: 0.0543 - val_mae: 0.1724
# Epoch 135/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0538 - mae: 0.1725 - val_loss: 0.0543 - val_mae: 0.1723
# Epoch 136/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0515 - mae: 0.1684 - val_loss: 0.0542 - val_mae: 0.1721
# Epoch 137/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0548 - mae: 0.1759 - val_loss: 0.0542 - val_mae: 0.1720
# Epoch 138/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0539 - mae: 0.1744 - val_loss: 0.0542 - val_mae: 0.1719
# Epoch 139/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0527 - mae: 0.1708 - val_loss: 0.0542 - val_mae: 0.1717
# Epoch 140/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0536 - mae: 0.1719 - val_loss: 0.0541 - val_mae: 0.1716
# Epoch 141/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0527 - mae: 0.1698 - val_loss: 0.0541 - val_mae: 0.1715
# Epoch 142/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0532 - mae: 0.1711 - val_loss: 0.0541 - val_mae: 0.1714
# Epoch 143/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0532 - mae: 0.1711 - val_loss: 0.0541 - val_mae: 0.1712
# Epoch 144/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0529 - mae: 0.1709 - val_loss: 0.0540 - val_mae: 0.1711
# Epoch 145/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0535 - mae: 0.1720 - val_loss: 0.0540 - val_mae: 0.1710
# Epoch 146/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0525 - mae: 0.1703 - val_loss: 0.0540 - val_mae: 0.1709
# Epoch 147/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0535 - mae: 0.1715 - val_loss: 0.0540 - val_mae: 0.1708
# Epoch 148/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0529 - mae: 0.1693 - val_loss: 0.0540 - val_mae: 0.1707
# Epoch 149/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0540 - mae: 0.1722 - val_loss: 0.0539 - val_mae: 0.1705
# Epoch 150/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0533 - mae: 0.1712 - val_loss: 0.0539 - val_mae: 0.1705
# Epoch 151/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0517 - mae: 0.1683 - val_loss: 0.0539 - val_mae: 0.1703
# Epoch 152/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0532 - mae: 0.1700 - val_loss: 0.0539 - val_mae: 0.1703
# Epoch 153/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0525 - mae: 0.1694 - val_loss: 0.0539 - val_mae: 0.1702
# Epoch 154/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0530 - mae: 0.1713 - val_loss: 0.0539 - val_mae: 0.1701
# Epoch 155/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0533 - mae: 0.1693 - val_loss: 0.0538 - val_mae: 0.1700
# Epoch 156/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0527 - mae: 0.1692 - val_loss: 0.0538 - val_mae: 0.1699
# Epoch 157/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0528 - mae: 0.1703 - val_loss: 0.0538 - val_mae: 0.1698
# Epoch 158/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0537 - mae: 0.1699 - val_loss: 0.0538 - val_mae: 0.1697
# Epoch 159/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0520 - mae: 0.1680 - val_loss: 0.0538 - val_mae: 0.1697
# Epoch 160/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0528 - mae: 0.1698 - val_loss: 0.0538 - val_mae: 0.1696
# Epoch 161/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0526 - mae: 0.1683 - val_loss: 0.0538 - val_mae: 0.1695
# Epoch 162/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0531 - mae: 0.1699 - val_loss: 0.0537 - val_mae: 0.1694
# Epoch 163/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0520 - mae: 0.1677 - val_loss: 0.0537 - val_mae: 0.1693
# Epoch 164/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0533 - mae: 0.1704 - val_loss: 0.0537 - val_mae: 0.1692
# Epoch 165/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0523 - mae: 0.1671 - val_loss: 0.0537 - val_mae: 0.1692
# Epoch 166/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0515 - mae: 0.1658 - val_loss: 0.0537 - val_mae: 0.1691
# Epoch 167/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0531 - mae: 0.1683 - val_loss: 0.0537 - val_mae: 0.1690
# Epoch 168/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0523 - mae: 0.1673 - val_loss: 0.0537 - val_mae: 0.1690
# Epoch 169/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0519 - mae: 0.1664 - val_loss: 0.0536 - val_mae: 0.1689
# Epoch 170/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0534 - mae: 0.1711 - val_loss: 0.0536 - val_mae: 0.1688
# Epoch 171/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0530 - mae: 0.1690 - val_loss: 0.0536 - val_mae: 0.1687
# Epoch 172/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0531 - mae: 0.1701 - val_loss: 0.0536 - val_mae: 0.1687
# Epoch 173/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0526 - mae: 0.1682 - val_loss: 0.0536 - val_mae: 0.1686
# Epoch 174/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0530 - mae: 0.1688 - val_loss: 0.0536 - val_mae: 0.1686
# Epoch 175/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0524 - mae: 0.1679 - val_loss: 0.0536 - val_mae: 0.1685
# Epoch 176/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0532 - mae: 0.1699 - val_loss: 0.0536 - val_mae: 0.1685
# Epoch 177/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0520 - mae: 0.1671 - val_loss: 0.0536 - val_mae: 0.1684
# Epoch 178/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0514 - mae: 0.1663 - val_loss: 0.0535 - val_mae: 0.1683
# Epoch 179/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0514 - mae: 0.1646 - val_loss: 0.0535 - val_mae: 0.1683
# Epoch 180/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0538 - mae: 0.1702 - val_loss: 0.0535 - val_mae: 0.1683
# Epoch 181/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0533 - mae: 0.1688 - val_loss: 0.0535 - val_mae: 0.1682
# Epoch 182/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0528 - mae: 0.1679 - val_loss: 0.0535 - val_mae: 0.1682
# Epoch 183/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0538 - mae: 0.1690 - val_loss: 0.0535 - val_mae: 0.1681
# Epoch 184/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0519 - mae: 0.1674 - val_loss: 0.0535 - val_mae: 0.1681
# Epoch 185/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0524 - mae: 0.1673 - val_loss: 0.0535 - val_mae: 0.1680
# Epoch 186/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0521 - mae: 0.1662 - val_loss: 0.0535 - val_mae: 0.1679
# Epoch 187/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0524 - mae: 0.1656 - val_loss: 0.0535 - val_mae: 0.1679
# Epoch 188/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0527 - mae: 0.1684 - val_loss: 0.0535 - val_mae: 0.1678
# Epoch 189/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0525 - mae: 0.1669 - val_loss: 0.0534 - val_mae: 0.1678
# Epoch 190/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0520 - mae: 0.1639 - val_loss: 0.0534 - val_mae: 0.1678
# Epoch 191/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0524 - mae: 0.1686 - val_loss: 0.0534 - val_mae: 0.1677
# Epoch 192/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0527 - mae: 0.1669 - val_loss: 0.0534 - val_mae: 0.1677
# Epoch 193/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0525 - mae: 0.1677 - val_loss: 0.0534 - val_mae: 0.1676
# Epoch 194/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0524 - mae: 0.1663 - val_loss: 0.0534 - val_mae: 0.1676
# Epoch 195/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0531 - mae: 0.1678 - val_loss: 0.0534 - val_mae: 0.1675
# Epoch 196/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0515 - mae: 0.1656 - val_loss: 0.0534 - val_mae: 0.1675
# Epoch 197/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0526 - mae: 0.1657 - val_loss: 0.0534 - val_mae: 0.1674
# Epoch 198/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0523 - mae: 0.1664 - val_loss: 0.0534 - val_mae: 0.1674
# Epoch 199/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0511 - mae: 0.1636 - val_loss: 0.0534 - val_mae: 0.1674
# Epoch 200/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0533 - mae: 0.1689 - val_loss: 0.0534 - val_mae: 0.1673
# Epoch 201/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0527 - mae: 0.1676 - val_loss: 0.0533 - val_mae: 0.1673
# Epoch 202/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0524 - mae: 0.1659 - val_loss: 0.0533 - val_mae: 0.1672
# Epoch 203/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0525 - mae: 0.1675 - val_loss: 0.0533 - val_mae: 0.1672
# Epoch 204/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0537 - mae: 0.1689 - val_loss: 0.0533 - val_mae: 0.1672
# Epoch 205/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0526 - mae: 0.1667 - val_loss: 0.0533 - val_mae: 0.1671
# Epoch 206/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0532 - mae: 0.1680 - val_loss: 0.0533 - val_mae: 0.1671
# Epoch 207/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0514 - mae: 0.1644 - val_loss: 0.0533 - val_mae: 0.1670
# Epoch 208/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0525 - mae: 0.1670 - val_loss: 0.0533 - val_mae: 0.1670
# Epoch 209/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0523 - mae: 0.1664 - val_loss: 0.0533 - val_mae: 0.1670
# Epoch 210/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0514 - mae: 0.1657 - val_loss: 0.0533 - val_mae: 0.1669
# Epoch 211/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0528 - mae: 0.1679 - val_loss: 0.0533 - val_mae: 0.1669
# Epoch 212/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0524 - mae: 0.1674 - val_loss: 0.0533 - val_mae: 0.1669
# Epoch 213/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0522 - mae: 0.1659 - val_loss: 0.0533 - val_mae: 0.1668
# Epoch 214/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0526 - mae: 0.1670 - val_loss: 0.0533 - val_mae: 0.1668
# Epoch 215/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0521 - mae: 0.1659 - val_loss: 0.0533 - val_mae: 0.1668
# Epoch 216/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0528 - mae: 0.1674 - val_loss: 0.0532 - val_mae: 0.1667
# Epoch 217/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0531 - mae: 0.1677 - val_loss: 0.0532 - val_mae: 0.1667
# Epoch 218/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0521 - mae: 0.1653 - val_loss: 0.0532 - val_mae: 0.1667
# Epoch 219/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0528 - mae: 0.1682 - val_loss: 0.0532 - val_mae: 0.1667
# Epoch 220/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0517 - mae: 0.1638 - val_loss: 0.0532 - val_mae: 0.1667
# Epoch 221/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0521 - mae: 0.1664 - val_loss: 0.0532 - val_mae: 0.1666
# Epoch 222/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0519 - mae: 0.1651 - val_loss: 0.0532 - val_mae: 0.1666
# Epoch 223/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0513 - mae: 0.1637 - val_loss: 0.0532 - val_mae: 0.1665
# Epoch 224/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0517 - mae: 0.1639 - val_loss: 0.0532 - val_mae: 0.1665
# Epoch 225/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0528 - mae: 0.1683 - val_loss: 0.0532 - val_mae: 0.1665
# Epoch 226/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0515 - mae: 0.1627 - val_loss: 0.0532 - val_mae: 0.1665
# Epoch 227/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0523 - mae: 0.1657 - val_loss: 0.0532 - val_mae: 0.1664
# Epoch 228/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0515 - mae: 0.1639 - val_loss: 0.0532 - val_mae: 0.1664
# Epoch 229/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0527 - mae: 0.1668 - val_loss: 0.0532 - val_mae: 0.1664
# Epoch 230/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0524 - mae: 0.1658 - val_loss: 0.0532 - val_mae: 0.1664
# Epoch 231/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0517 - mae: 0.1641 - val_loss: 0.0532 - val_mae: 0.1664
# Epoch 232/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0518 - mae: 0.1637 - val_loss: 0.0532 - val_mae: 0.1664
# Epoch 233/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0524 - mae: 0.1665 - val_loss: 0.0532 - val_mae: 0.1664
# Epoch 234/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0528 - mae: 0.1674 - val_loss: 0.0532 - val_mae: 0.1663
# Epoch 235/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0518 - mae: 0.1650 - val_loss: 0.0532 - val_mae: 0.1663
# Epoch 236/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0518 - mae: 0.1661 - val_loss: 0.0531 - val_mae: 0.1663
# Epoch 237/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0526 - mae: 0.1672 - val_loss: 0.0531 - val_mae: 0.1662
# Epoch 238/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0520 - mae: 0.1651 - val_loss: 0.0531 - val_mae: 0.1662
# Epoch 239/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0518 - mae: 0.1638 - val_loss: 0.0531 - val_mae: 0.1662
# Epoch 240/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0514 - mae: 0.1650 - val_loss: 0.0531 - val_mae: 0.1662
# Epoch 241/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0539 - mae: 0.1676 - val_loss: 0.0531 - val_mae: 0.1662
# Epoch 242/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0509 - mae: 0.1633 - val_loss: 0.0531 - val_mae: 0.1661
# Epoch 243/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0513 - mae: 0.1636 - val_loss: 0.0531 - val_mae: 0.1661
# Epoch 244/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0523 - mae: 0.1653 - val_loss: 0.0531 - val_mae: 0.1661
# Epoch 245/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0523 - mae: 0.1654 - val_loss: 0.0531 - val_mae: 0.1661
# Epoch 246/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0519 - mae: 0.1635 - val_loss: 0.0531 - val_mae: 0.1661
# Epoch 247/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0533 - mae: 0.1694 - val_loss: 0.0531 - val_mae: 0.1660
# Epoch 248/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0521 - mae: 0.1654 - val_loss: 0.0531 - val_mae: 0.1660
# Epoch 249/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0520 - mae: 0.1642 - val_loss: 0.0531 - val_mae: 0.1660
# Epoch 250/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0509 - mae: 0.1639 - val_loss: 0.0531 - val_mae: 0.1660
# Epoch 251/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.0513 - mae: 0.1638 - val_loss: 0.0531 - val_mae: 0.1660
# Epoch 252/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0512 - mae: 0.1628 - val_loss: 0.0531 - val_mae: 0.1660
# Epoch 253/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0517 - mae: 0.1648 - val_loss: 0.0531 - val_mae: 0.1659
# Epoch 254/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0522 - mae: 0.1644 - val_loss: 0.0531 - val_mae: 0.1659
# Epoch 255/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0524 - mae: 0.1661 - val_loss: 0.0531 - val_mae: 0.1659
# Epoch 256/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0515 - mae: 0.1644 - val_loss: 0.0531 - val_mae: 0.1659
# Epoch 257/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0521 - mae: 0.1651 - val_loss: 0.0531 - val_mae: 0.1658
# Epoch 258/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0522 - mae: 0.1659 - val_loss: 0.0531 - val_mae: 0.1658
# Epoch 259/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0525 - mae: 0.1669 - val_loss: 0.0530 - val_mae: 0.1658
# Epoch 260/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0526 - mae: 0.1671 - val_loss: 0.0530 - val_mae: 0.1658
# Epoch 261/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0525 - mae: 0.1655 - val_loss: 0.0530 - val_mae: 0.1658
# Epoch 262/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0518 - mae: 0.1654 - val_loss: 0.0530 - val_mae: 0.1658
# Epoch 263/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0528 - mae: 0.1661 - val_loss: 0.0530 - val_mae: 0.1658
# Epoch 264/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0517 - mae: 0.1632 - val_loss: 0.0530 - val_mae: 0.1658
# Epoch 265/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0527 - mae: 0.1680 - val_loss: 0.0530 - val_mae: 0.1658
# Epoch 266/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0510 - mae: 0.1632 - val_loss: 0.0530 - val_mae: 0.1657
# Epoch 267/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0525 - mae: 0.1647 - val_loss: 0.0530 - val_mae: 0.1657
# Epoch 268/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0515 - mae: 0.1645 - val_loss: 0.0530 - val_mae: 0.1657
# Epoch 269/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0529 - mae: 0.1667 - val_loss: 0.0530 - val_mae: 0.1657
# Epoch 270/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0514 - mae: 0.1639 - val_loss: 0.0530 - val_mae: 0.1657
# Epoch 271/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0521 - mae: 0.1651 - val_loss: 0.0530 - val_mae: 0.1657
# Epoch 272/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0526 - mae: 0.1671 - val_loss: 0.0530 - val_mae: 0.1656
# Epoch 273/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0508 - mae: 0.1631 - val_loss: 0.0530 - val_mae: 0.1656
# Epoch 274/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0530 - mae: 0.1668 - val_loss: 0.0530 - val_mae: 0.1656
# Epoch 275/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0521 - mae: 0.1642 - val_loss: 0.0530 - val_mae: 0.1656
# Epoch 276/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0513 - mae: 0.1656 - val_loss: 0.0530 - val_mae: 0.1655
# Epoch 277/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0515 - mae: 0.1626 - val_loss: 0.0530 - val_mae: 0.1655
# Epoch 278/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0530 - mae: 0.1652 - val_loss: 0.0530 - val_mae: 0.1655
# Epoch 279/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0511 - mae: 0.1637 - val_loss: 0.0530 - val_mae: 0.1655
# Epoch 280/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0514 - mae: 0.1627 - val_loss: 0.0530 - val_mae: 0.1655
# Epoch 281/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0524 - mae: 0.1665 - val_loss: 0.0530 - val_mae: 0.1655
# Epoch 282/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0521 - mae: 0.1666 - val_loss: 0.0530 - val_mae: 0.1654
# Epoch 283/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0514 - mae: 0.1634 - val_loss: 0.0530 - val_mae: 0.1655
# Epoch 284/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0526 - mae: 0.1666 - val_loss: 0.0530 - val_mae: 0.1654
# Epoch 285/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0523 - mae: 0.1651 - val_loss: 0.0530 - val_mae: 0.1654
# Epoch 286/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0527 - mae: 0.1673 - val_loss: 0.0530 - val_mae: 0.1654
# Epoch 287/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0519 - mae: 0.1648 - val_loss: 0.0529 - val_mae: 0.1654
# Epoch 288/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0519 - mae: 0.1653 - val_loss: 0.0529 - val_mae: 0.1654
# Epoch 289/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0530 - mae: 0.1662 - val_loss: 0.0529 - val_mae: 0.1654
# Epoch 290/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0518 - mae: 0.1635 - val_loss: 0.0529 - val_mae: 0.1654
# Epoch 291/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0512 - mae: 0.1635 - val_loss: 0.0529 - val_mae: 0.1654
# Epoch 292/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0517 - mae: 0.1642 - val_loss: 0.0529 - val_mae: 0.1654
# Epoch 293/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0520 - mae: 0.1643 - val_loss: 0.0529 - val_mae: 0.1654
# Epoch 294/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.0529 - mae: 0.1675 - val_loss: 0.0529 - val_mae: 0.1653
# Epoch 295/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0512 - mae: 0.1622 - val_loss: 0.0529 - val_mae: 0.1653
# Epoch 296/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0509 - mae: 0.1622 - val_loss: 0.0529 - val_mae: 0.1653
# Epoch 297/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0516 - mae: 0.1631 - val_loss: 0.0529 - val_mae: 0.1653
# Epoch 298/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0509 - mae: 0.1640 - val_loss: 0.0529 - val_mae: 0.1653
# Epoch 299/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0523 - mae: 0.1652 - val_loss: 0.0529 - val_mae: 0.1653
# Epoch 300/300
# 40/40 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0523 - mae: 0.1644 - val_loss: 0.0529 - val_mae: 0.1653
# train_MSE: 0.05181349068880081
# train_MAE: 0.1641736924648285
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 752us/step - loss: 0.0536 - mae: 0.1668
# val_MSE: 0.05290992185473442, val_MAE: 0.1652674674987793
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 742us/step - loss: 0.0494 - mae: 0.1611
# test_MSE: 0.05089953541755676, test_MAE: 0.1618967205286026

# %%
# Make predictions on the test set
y_pred = model.predict(X_test)

y_pred_inv = scalerY.inverse_transform(y_pred.reshape(-1, 50))

y_test_inv = scalerY.inverse_transform(y_test.reshape(-1, 50))


diff_min = np.min(np.abs(y_test_inv - y_pred_inv))
diff_max = np.max(np.abs(y_test_inv - y_pred_inv))

# Select a random index for a 5x10 segment
random_index = np.random.randint(0, len(y_test))
actual_segment = pd.DataFrame(y_test_inv).iloc[random_index].values.reshape(5, 10)
predicted_segment = y_pred_inv[random_index].reshape(5, 10)

x = range(1, 11)

# Plot the selected segments
fig, axs = plt.subplots(5, 1, figsize=(10, 10), sharex=True)
for i in range(5):
    axs[i].plot(x, actual_segment[i], 'b.-', label='Actual Temperature')
    axs[i].plot(x, predicted_segment[i], 'r.-', label='Predicted Temperature')
    plt.xlabel('Layer')
    plt.xticks(np.arange(1, 11, step=1))
    axs[i].set_ylabel('Temperature')
    axs[i].legend()
    axs[i].grid(True)

plt.xlabel('Layer')
plt.suptitle(f"Actual vs Predicted Temperatures on Sample {random_index} for all 5 Time Intervals")
plt.show()
# Out:
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step

# %%
actual_std = np.std(y_test)
pred_std = np.std(y_pred)

# %%
print(actual_std)
print(pred_std)
# Out:
# 0.15333296787697823
# 0.15879928

# %%
actual_temp = pd.DataFrame(y_test_inv).iloc[i].values.reshape(5, 10)
predicted_temp = pd.DataFrame(y_pred_inv).iloc[i].values.reshape(5, 10)

actual_temp.shape
predicted_temp.shape
# Out:
# (5, 10)

# %%
all_diff = []
for i in range(len(y_test)):
    actual_temp = pd.DataFrame(y_test_inv).iloc[i].values.reshape(5, 10)
    predicted_temp = y_pred_inv[i].reshape(5, 10)

    diff = actual_temp - predicted_temp

    all_diff.append(diff[None,:])

complete_diff = np.vstack(all_diff)

# len(complete_diff)

column_sums = np.sum(complete_diff, axis=1)

avg_temp_diff = column_sums / 5

# print("Array:\n", complete_diff)
# print("Sum of columns for each depth level:\n", column_sums)

avg_temp_diff

# random_index = np.random.randint(0, len(avg_temp_diff))
row_values = avg_temp_diff[random_index]

x = range(1, 11)

plt.figure(figsize=(10,6))
plt.bar(x, row_values, color='blue')

plt.title(f"Bar Graph of Average Temperature Difference in Each Layer for Sample {random_index+1}")
plt.xlabel("Layer")
plt.xticks(np.arange(1, 11, step=1))
plt.ylabel("Average Temperature Difference")

plt.figure(figsize=(10,6))
plt.plot(x, row_values, label=f"Sample {random_index+1}", color="r", linestyle='-', marker='o')

plt.title(f"Plot of Average Temperature Difference for Sample {random_index+1}")
plt.xlabel("Layer")
plt.xticks(np.arange(1, 11, step=1))
plt.ylabel("Average Temperature Difference")

plt.show()

# %%
# Create a figure and axis
fig, ax = plt.subplots(figsize=(10, 6))

# Plot each column of data
for i in range(10):
    ax.plot([i+1] * 400, avg_temp_diff[:, i], 'o', markersize=1)

# Set the x-axis limits
ax.set_xlim(0.5, 10.5)

# Label the x-axis and y-axis
ax.set_xlabel('Layer')
plt.xticks(np.arange(1, 11, step=1))
ax.set_ylabel('Temperature Difference')

# Set the title
ax.set_title('Plot of Temperature Differences of Each Test Sample for Each Layer')

# Show the plot
plt.show()

# %%
diff = np.abs(y_test_inv - y_pred_inv)

diff_sum = np.sum(diff, axis=0)

diff_sum = diff_sum.reshape(5, 10)
diff_avg = np.sum(diff_sum, axis=0) / 2000
diff_avg
# Out:
# array([10.20712334, 10.39020204, 21.37179577, 15.51628505,  9.86202215,
#        15.2673506 , 26.19766498, 19.3541347 , 10.11283912, 15.35594449])

# %%
np.mean(diff_avg)
# Out:
# 15.363536222335549

# %%
x = range(1, len(diff_avg) + 1)
plt.figure(figsize=(16, 10))
plt.plot(x, diff_avg, marker='o', color='g')
plt.xlim(0.5, 10.5)
plt.title("Mean Absolute Difference of Temperature Predictions in Each Layer")

plt.xlabel("Layer")
plt.xticks(np.arange(1, 11, step=1))
plt.ylabel("Mean Absolute Temperature Difference")
plt.yticks(np.arange(math.floor(np.min(diff_avg)), math.ceil(np.max(diff_avg)), step=.5))

plt.show()

# %%
plt.figure(figsize=(16, 10))

# Plot horizontal bar graph
bars = plt.barh(x, diff_avg, color='orange')

# Set the x-axis limits if needed
plt.xlim(math.floor(np.min(diff_avg)), math.ceil(np.max(diff_avg)) + 1)

# Add title and labels
plt.title("Average Absolute Temperature Difference in Feed-forward Model")
plt.ylabel("Layer")
plt.xlabel("Absolute Temperature Difference (K)")

# Set y-ticks for layers
plt.yticks(np.arange(1, 11, step=1))

# Set x-ticks for temperature difference
plt.xticks(np.arange(math.floor(np.min(diff_avg)) - 1, math.ceil(np.max(diff_avg)) + 1, step=1))

# Add labels to each bar
for bar in bars:
    width = bar.get_width()
    plt.text(width + 0.1, bar.get_y() + bar.get_height() / 2, f'{width:.2f}', 
             ha='left', va='center')

plt.show()

# %%
actual = np.sum(y_test_inv, axis=0)

actual = actual.reshape(5, 10)
actual_avg = np.sum(actual, axis=0) / 2000

avg_relative_diff = (diff_avg / actual_avg) * 100

x = range(1, len(diff_avg) + 1)
plt.figure(figsize=(16, 10))
plt.plot(x, avg_relative_diff, marker='o', color='g')
plt.xlim(0.5, 10.5)
plt.title("Mean Absolute Difference of Temperature Predictions in Each Layer")

plt.xlabel("Layer")
plt.xticks(np.arange(1, 11, step=1))
plt.ylabel("Average Relative Temperature Difference")
plt.yticks(np.arange(math.floor(np.min(avg_relative_diff)), math.ceil(np.max(avg_relative_diff)), step=1))

plt.show()
